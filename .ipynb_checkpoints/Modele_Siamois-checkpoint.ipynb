# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import keras
import import_ipynb
import random 
import math
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras import layers, models, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import backend as K
from PIL import Image
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split 
from tensorflow.keras.applications import VGG16
from sklearn.decomposition import PCA


# 1. Configuration des chemins et paramètres
test_dir = r"D:\Lucie\Insa Toulouse\4A\Projet\petit_test"
og_dir = r"D:\Lucie\Insa Toulouse\4A\Projet\petit"
train_dir = r"D:\Lucie\Insa Toulouse\4A\Projet\petit_modifiees"

size_image_x=120
size_image_y=120
input_shape = (size_image_x, size_image_y, 1)

# %%
# Fonction pour charger les images locales
def load_local_images(dataset_path, image_size=(256, 256)):
    images = []
    labels = []
    class_names = sorted(os.listdir(dataset_path))  # Liste des classes

    for label, class_name in enumerate(class_names):
        class_dir = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_dir):
            continue  # Ignorer les fichiers non répertoires

        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            
            # Charger et convertir l'image
            img = load_img(img_path, target_size=image_size, color_mode="grayscale")  
            img_array = img_to_array(img) / 255.0  # Normalisation
            images.append(img_array)
            labels.append(label)

    return np.array(images), np.array(labels)
    
def create_pairs(images, labels):
    imagePairs = []
    labelPairs = []

    num_classes = len(np.unique(labels))
    idx = [np.where(labels == i)[0] for i in range(num_classes)]

    for ind in range(len(images)):
        currImage = images[ind]
        label = labels[ind]

        # Trouver une autre image de la même classe
        indB = np.random.choice(idx[label])
        posImage = images[indB]
        imagePairs.append([currImage, posImage])
        labelPairs.append(1)  # Même classe -> 1

        # Trouver une image d'une autre classe
        neg_idx = np.where(labels != label)[0]
        negImage = images[np.random.choice(neg_idx)]
        imagePairs.append([currImage, negImage])
        labelPairs.append(0)  # Classe différente -> 0

    return np.array(imagePairs, dtype=np.float32), np.array(labelPairs, dtype=np.int32)

x_test, y_test = load_local_images(train_dir)
#x_test = np.expand_dims(x_test, axis=-1)
pairs, labels_pairs = create_pairs(x_test, y_test)
print(f"Nombre total de paires générées : {len(pairs)}")



# Fonction pour charger les images locales
def load_local_images(dataset_path, image_size=(256, 256)):
    images = []
    labels = []
    class_names = sorted(os.listdir(dataset_path))  # Liste des classes

    for label, class_name in enumerate(class_names):
        class_dir = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_dir):
            continue  # Ignorer les fichiers non répertoires

        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            
            # Charger et convertir l'image
            img = load_img(img_path, target_size=image_size, color_mode="grayscale")  
            img_array = img_to_array(img) / 255.0  # Normalisation
            images.append(img_array)
            labels.append(label)

    return np.array(images), np.array(labels)
    
def create_pairs(images, labels):
    imagePairs = []
    labelPairs = []

    num_classes = len(np.unique(labels))
    idx = [np.where(labels == i)[0] for i in range(num_classes)]

    for ind in range(len(images)):
        currImage = images[ind]
        label = labels[ind]

        # Trouver une autre image de la même classe
        indB = np.random.choice(idx[label])
        posImage = images[indB]
        imagePairs.append([currImage, posImage])
        labelPairs.append(1)  # Même classe -> 1

        # Trouver une image d'une autre classe
        neg_idx = np.where(labels != label)[0]
        negImage = images[np.random.choice(neg_idx)]
        imagePairs.append([currImage, negImage])
        labelPairs.append(0)  # Classe différente -> 0

    return np.array(imagePairs, dtype=np.float32), np.array(labelPairs, dtype=np.int32)

x_test, y_test = load_local_images(train_dir)
#x_test = np.expand_dims(x_test, axis=-1)
pairs, labels_pairs = create_pairs(x_test, y_test)
print(f"Nombre total de paires générées : {len(pairs)}")
# Out:
# Nombre total de paires générées : 3834
# Nombre total de paires générées : 3834

# %%
########################
###### Modèle Siamois ######
# 4. Création du modèle Siamese
input_shape = (size_image_y, size_image_x, 1)

import tensorflow.keras.backend as K
def contrastive_loss(y_true, y_pred):
    margin = 1.0
    return K.mean(y_true * K.square(y_pred) + (1 - y_true) * K.square(K.maximum(margin - y_pred, 0)))


def create_siamese_model(input_shape):
    """Crée et retourne le modèle Siamese."""
    
    input_img = Input(shape=input_shape)
    
    x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(input_img)
    x = BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.2)(x)
    """
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
"""
    output = keras.layers.GlobalAveragePooling2D()(x)  # Reduce spatial dimensions
    #output = layers.Flatten()(output)
    output = keras.layers.Dense(400, activation="sigmoid")(output)
    """
    
    x = layers.Flatten()(x)
    #x = layers.Dense(64, activation='relu')(x)  # Réduction de la taille du vecteur
    x = layers.Dense(128, activation='relu')(x)  # Augmente légèrement la complexité
    """
    output = layers.Dropout(0.3)(output)
    
    siamese = Model(input_img, output, name="siamese")
    siamese.summary()
    
    input_img_1 = Input(shape=input_shape)
    input_img_2 = Input(shape=input_shape)

    encoded_1 = siamese(input_img_1)

    encoded_2 = siamese(input_img_2)

    #distance = layers.Lambda(lambda tensors: tf.abs(tensors[0] - tensors[1]))([encoded_1, encoded_2])
    distance = layers.Lambda(lambda tensors: tf.sqrt(tf.reduce_sum(tf.square(tensors[0] - tensors[1]), axis=1, keepdims=True)))([encoded_1, encoded_2])
    output = layers.Dense(1, activation='sigmoid')(distance)

    siamese_model = Model(inputs=[input_img_1, input_img_2], outputs=output)
    return siamese_model

siamese_model = create_siamese_model(input_shape)

# 6. Compilation et callbacks
#siamese_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])
#siamese_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#siamese_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss=contrastive_loss, metrics=['accuracy'])
siamese_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
# Séparer les paires en deux entrées distinctes
X1 = pairs[:, 0]  # Première image de la paire
X2 = pairs[:, 1]  # Deuxième image de la paire
y = labels_pairs   # Labels (1 si similaires, 0 sinon)

# Création des indices pour les paires
indices = np.arange(len(X1))  # Liste d'indices correspondant aux paires

# Division des indices pour garder les paires intactes
indices_train, indices_val = train_test_split(indices, test_size=0.2, random_state=42)

# Application de la division des indices à X1, X2, et y
X1_train, X2_train, y_train = X1[indices_train], X2[indices_train], y[indices_train]
X1_val, X2_val, y_val = X1[indices_val], X2[indices_val], y[indices_val]

# Redimensionner les images comme avant
X1_train = np.array([cv2.resize(x, (size_image_x, size_image_y)) for x in X1_train], dtype=np.float32)
X2_train = np.array([cv2.resize(x, (size_image_x, size_image_y)) for x in X2_train], dtype=np.float32)

X1_val = np.array([cv2.resize(x, (size_image_x, size_image_y)) for x in X1_val], dtype=np.float32)
X2_val = np.array([cv2.resize(x, (size_image_x, size_image_y)) for x in X2_val], dtype=np.float32)

# Reshaper les labels
y_train = y_train.reshape(-1, 1)
y_val = y_val.reshape(-1, 1)

# Vérification de la cohérence des paires
assert len(X1_train) == len(X2_train) == len(y_train)
assert len(X1_val) == len(X2_val) == len(y_val)

def convert_to_gray(images):
    gray_images = []
    for img in images:
        if img is None:
            raise ValueError("Erreur : Une image n'a pas été chargée correctement.")

        # Vérifier si l'image est déjà en grayscale
        if len(img.shape) == 2:  # Image au format (H, W)
            img = np.expand_dims(img, axis=-1)  # Ajouter une dimension (H, W, 1)
        elif img.shape[-1] == 3:  # Image au format (H, W, 3) (RGB)
            img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # Convertir en grayscale
            img = np.expand_dims(img, axis=-1)  # Ajouter une dimension (H, W, 1)

        gray_images.append(img)

    return np.array(gray_images)

# Appliquer la conversion sur les ensembles d'entraînement et de validation
X1_train = convert_to_gray(X1_train)
X2_train = convert_to_gray(X2_train)
X1_val = convert_to_gray(X1_val)
X2_val = convert_to_gray(X2_val)

# Entraîner le modèle siamois
history = siamese_model.fit([X1_train, X2_train], y_train, 
                  validation_data=([X1_val, X2_val], y_val), 
                  epochs=10, 
                  batch_size=8, 
                  #callbacks=[early_stopping, reduce_lr]  # Ajout du callback ReduceLROnPlateau
)


# Courbes de perte
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Perte d\'entraînement')
plt.plot(history.history['val_loss'], label='Perte de validation')
plt.title("Perte pendant l'entraînement et la validation")
plt.xlabel("Epochs")
plt.ylabel("Perte")
plt.legend()
plt.grid(True)
plt.show()

# Courbes d'exactitude
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Exactitude d\'entraînement')
plt.plot(history.history['val_accuracy'], label='Exactitude de validation')
plt.title("Exactitude pendant l'entraînement et la validation")
plt.xlabel("Epochs")
plt.ylabel("Exactitude")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model: "siamese"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 120, 120, 1)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 120, 120, 8)         │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 120, 120, 8)         │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 60, 60, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 60, 60, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 60, 60, 16)          │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 60, 60, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 30, 30, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 30, 30, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 16)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 400)                 │           6,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 400)                 │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,144 (31.81 KB)
#  Trainable params: 8,096 (31.62 KB)
#  Non-trainable params: 48 (192.00 B)
# Epoch 1/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.5056 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 2/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.4859 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 3/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - accuracy: 0.5167 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 4/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.5057 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 5/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.5075 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 6/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - accuracy: 0.5116 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 7/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.5067 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 8/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.4915 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 9/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.5219 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00
# Epoch 10/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.5087 - loss: 0.0000e+00 - val_accuracy: 0.4772 - val_loss: 0.0000e+00

# %%
##################################
### test amélioration -> voir avant couche dense
def visualiser_paire(idx, label):
    """Affiche la comparaison pour une paire donnée (idx) dans le jeu de validation."""
    
    image1 = np.expand_dims(X1_val[idx], axis=0)  # Ajouter batch dim
    image2 = np.expand_dims(X2_val[idx], axis=0)

    # Récupérer l'encodeur Siamese
    encoder_siamois = siamese_model.get_layer("siamese")  

    # 🔹 EXTRACTION DES REPRESENTATIONS LATENTES (Dense)
    latent1 = encoder_siamois.predict(image1)  
    latent2 = encoder_siamois.predict(image2)  

    # 🔹 Trouver la dernière couche 2D avant GlobalAveragePooling2D
    last_conv_layer = None
    for layer in reversed(encoder_siamois.layers):
        if isinstance(layer, layers.Conv2D) or isinstance(layer, layers.MaxPooling2D):
            last_conv_layer = layer
            break

    if last_conv_layer is None:
        raise ValueError("Aucune couche 2D trouvée avant GlobalAveragePooling2D ! Vérifiez l'architecture.")

    model_intermediaire = Model(inputs=encoder_siamois.input, outputs=last_conv_layer.output)
    
    feature_map1 = model_intermediaire.predict(image1)  # Features avant Dense (Image 1)
    feature_map2 = model_intermediaire.predict(image2)  # Features avant Dense (Image 2)

    # 🔹 Normalisation des images pour imshow ([0,255] → [0,1])
    image1_display = np.clip(X1_val[idx] / 255.0, 0, 1)
    image2_display = np.clip(X2_val[idx] / 255.0, 0, 1)

    # Création de la figure
    fig, axes = plt.subplots(3, 3, figsize=(12, 10))

    # 🔹 Affichage des images d'origine
    axes[0, 0].imshow(image1_display)
    axes[0, 0].axis("off")
    axes[0, 0].set_title("Image 1 (Originale)")

    axes[0, 1].imshow(image2_display)
    axes[0, 1].axis("off")
    axes[0, 1].set_title("Image 2 (Comparée)")

    # 🔹 Vérification de la variance avant PCA
    if latent1.shape[1] > 2:
        if np.var(latent1) > 0 and np.var(latent2) > 0:
            pca = PCA(n_components=2)
            latent_pca = pca.fit_transform(np.vstack([latent1, latent2]))

            axes[1, 0].scatter(latent_pca[0, 0], latent_pca[0, 1], c="blue", label="Image 1")
            axes[1, 0].scatter(latent_pca[1, 0], latent_pca[1, 1], c="red", label="Image 2")
            axes[1, 0].legend()
            axes[1, 0].set_title("Représentation Latente (PCA)")
        else:
            axes[1, 0].text(0.5, 0.5, "Variance nulle (PCA impossible)", ha="center", va="center")
            axes[1, 0].axis("off")
    else:
        axes[1, 0].plot(latent1.flatten(), label="Image 1", color="blue")
        axes[1, 0].plot(latent2.flatten(), label="Image 2", color="red")
        axes[1, 0].legend()
        axes[1, 0].set_title("Représentation Latente (Vecteur)")

    # 🔹 Affichage de la différence absolue entre les représentations
    difference = np.abs(latent1 - latent2)
    axes[1, 1].bar(range(len(difference.flatten())), difference.flatten(), color="purple")
    axes[1, 1].set_title("Différence entre Représentations")

    # 🔹 Affichage de la dernière couche 2D avant la Dense (Feature Maps)
    mean_feature1 = np.mean(feature_map1[0], axis=-1)  # Moyenne des cartes de caractéristiques
    mean_feature2 = np.mean(feature_map2[0], axis=-1)

    axes[2, 0].imshow(mean_feature1, cmap="viridis")
    axes[2, 0].set_title("Feature Map Image 1")
    axes[2, 0].axis("off")

    axes[2, 1].imshow(mean_feature2, cmap="viridis")
    axes[2, 1].set_title("Feature Map Image 2")
    axes[2, 1].axis("off")

    # 🔹 Calcul et affichage de la similarité (sortie du modèle Siamese)
    similarity_score = siamese_model.predict([image1, image2])[0, 0]
    label_str = "Similaire" if label == 1 else "Différent"
    
    axes[0, 2].text(0.5, 0.6, f"Score de similarité: {similarity_score:.2f}", fontsize=14, ha="center", va="center")
    axes[0, 2].text(0.5, 0.3, f"Label réel: {label_str}", fontsize=14, color="red", ha="center", va="center")
    axes[0, 2].axis("off")

    plt.tight_layout()
    plt.show()


# ÉTAPE DE VÉRIFICATION : Histogramme des similarités
# Trouver les indices des similarités min et max pour les paires vraies
min_true_score_idx = np.argmin(true_pairs_scores)
max_true_score_idx = np.argmax(true_pairs_scores)

# Trouver les indices des similarités min et max pour les paires fausses
min_false_score_idx = np.argmin(false_pairs_scores)
max_false_score_idx = np.argmax(false_pairs_scores)

# Affichage des résultats
print(f"✅ Score minimum pour les paires vraies (similaires) : {true_pairs_scores[min_true_score_idx]:.4f}")
print(f"✅ Score maximum pour les paires vraies (similaires) : {true_pairs_scores[max_true_score_idx]:.4f}")
print(f"❌ Score minimum pour les paires fausses (différentes) : {false_pairs_scores[min_false_score_idx]:.4f}")
print(f"❌ Score maximum pour les paires fausses (différentes) : {false_pairs_scores[max_false_score_idx]:.4f}")


# Visualisation des paires avec les similarités minimales et maximales
print("\n🔹 Visualisation de la paire vraie avec la similarité minimale")
visualiser_paire(indices_positifs[min_true_score_idx], 1)
print("\n🔹 Visualisation de la paire vraie avec la similarité maximale")
visualiser_paire(indices_positifs[max_true_score_idx], 1)
print("\n🔹 Visualisation de la paire fausse avec la similarité minimale")
visualiser_paire(indices_negatifs[min_false_score_idx], 0)
print("\n🔹 Visualisation de la paire fausse avec la similarité maximale")
visualiser_paire(indices_negatifs[max_false_score_idx], 0)
# Out:
# 🔹 Visualisation d'une paire SIMILAIRE (Label = 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 🔹 Visualisation d'une paire DIFFÉRENTE (Label = 0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 🔹 Visualisation d'une paire SIMILAIRE (Label = 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 🔹 Visualisation d'une paire DIFFÉRENTE (Label = 0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 🔹 Visualisation d'une paire SIMILAIRE (Label = 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 🔹 Visualisation d'une paire DIFFÉRENTE (Label = 0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step

# %%
################################
####### Chargement données de test ######

# Dimensions pour le redimensionnement
resize_width, resize_height = 480, 256
name = []

"""def cropped_and_gray_image(img_path):
    #Charge une image, détecte un cercle, recadre autour et la convertit en niveaux de gris.
    # Charger l'image
    image0 = cv2.imread(img_path)

    if image0 is None:
        print(f"Erreur : Impossible de charger {img_path}")
        return None  # Retourner None au lieu de 'continue'

    # Redimensionner l'image à 480x256 pour la détection du cercle
    image = cv2.resize(image0, (resize_width, resize_height))

    # Convertir en niveaux de gris
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Détecter les cercles avec HoughCircles
    circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, dp=1.2, minDist=300, param1=100, param2=10, minRadius=100, maxRadius=200)

    # Dimensions de l'image redimensionnée
    height, width = gray.shape
    center_x, center_y = width // 2, height // 2

    # Sélectionner le cercle le plus proche du centre, mais uniquement s'il est entièrement visible
    best_circle = None
    min_distance = float("inf")

    if circles is not None:
        for circle in circles[0, :]:
            x, y, r = circle

            # Vérifier que le cercle est entièrement contenu dans l'image
            if (x - r >= 0 and y - r >= 0 and x + r <= width and y + r <= height):
                distance_to_center = np.sqrt((x - center_x) ** 2 + (y - center_y) ** 2)
                if distance_to_center < min_distance:
                    min_distance = distance_to_center
                    best_circle = circle
    
    # Si un cercle a été détecté et validé
    if best_circle is not None:
        x, y, r = best_circle  # Coordonnées du cercle sur l'image redimensionnée

        # Mise à l'échelle des coordonnées et du rayon
        scale_x = image0.shape[1] / resize_width
        scale_y = image0.shape[0] / resize_height
        x = int(x * scale_x)
        y = int(y * scale_y)
        r = int(r * min(scale_x, scale_y))  # Adapter le rayon

        # Définir la taille du carré basé sur le diamètre
        side = 2 * r  

        # Calculer les nouvelles coordonnées pour assurer un carré
        x1, y1 = x - r, y - r
        x2, y2 = x + r, y + r

        # Vérifier que les coordonnées restent dans les limites de l'image
        x1, y1 = max(0, x1), max(0, y1)
        x2, y2 = min(image0.shape[1], x2), min(image0.shape[0], y2)

        # Recadrer l'image sur l'image originale
        cropped_image = image0[y1:y2, x1:x2]

        # Convertir en noir et blanc
        cropped_gray = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2GRAY)
        return cropped_gray  # Retourner l'image recadrée et en niveaux de gris
    else : 
        print(f"Aucun cercle trouvé pour: {img_path}")
        return None

def load_and_preprocess_test_images(load_dir, size_image_x, size_image_y):
    #Charge, recadre et prétraite les images de test en niveaux de gris
    test_images = []
    valid_file_names = []  # Liste pour stocker les fichiers valides
    test_image_files = [f for f in os.listdir(load_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    for file in test_image_files:
        img_path = os.path.join(load_dir, file)
        try:
            img = cropped_and_gray_image(img_path)  # Récupérer l'image recadrée
            
            if img is not None:  # Si le recadrage a réussi
                img_resized = Image.fromarray(img).resize((size_image_x, size_image_y))
                img_array = np.array(img_resized) / 255.0  # Normalisation [0,1]
                test_images.append(img_array)
                valid_file_names.append(file)  # Ajouter uniquement si l'image est valide
            
        except Exception as e:
            print(f"❌ Erreur avec l'image {file}: {e}")

    if len(test_images) == 0:
        raise ValueError("❌ Aucune image de test chargée. Vérifiez le dossier des images de test.")

    return np.array(test_images), valid_file_names  # Retourne les noms filtrés"""




def load_and_preprocess_test_images(load_dir, size_image_x, size_image_y):
    #Charge, recadre et prétraite les images de test en niveaux de gris
    test_images = []
    test_image_files = [f for f in os.listdir(load_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    for file in test_image_files:
        file_path = os.path.join(load_dir, file)
        try:
            img = Image.open(file_path).convert("L")  # "L" = grayscale
            img_resized = img.resize((size_image_x, size_image_y))  # Redimensionner
            img_array = np.array(img_resized) / 255.0  # Normalisation [0,1]

            test_images.append(img_array)  # Ajouter à la liste
            test_image_files.append(file_path)  # Stocker le chemin du fichier
            
        except Exception as e:
            print(f"❌ Erreur avec l'image {file}: {e}")

    if len(test_images) == 0:
        raise ValueError("❌ Aucune image de test chargée. Vérifiez le dossier des images de test.")

    return np.array(test_images), valid_file_names  # Retourne les noms filtrés
    

def load_and_preprocess_original_images(base_dir, size_image_x, size_image_y):
    """Charge toutes les images des sous-dossiers de base_dir et les prétraite."""
    images = []  # Liste pour stocker les images
    image_files = []  # Liste pour stocker les noms de fichiers
    base_files = [f for f in os.listdir(base_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Explorer chaque sous-dossier (classe)
    for class_name in os.listdir(base_dir):
        class_path = os.path.join(base_dir, class_name)

        # Vérifier que c'est bien un dossier avant de le parcourir
        if os.path.isdir(class_path):  
            for file_name in os.listdir(class_path):
                file_path = os.path.join(class_path, file_name)
                
                # Vérifier si c'est une image
                if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                    try:
                        # Charger l'image en niveaux de gris
                        img = Image.open(file_path).convert("L")  # "L" = grayscale
                        img_resized = img.resize((size_image_x, size_image_y))  # Redimensionner
                        img_array = np.array(img_resized) / 255.0  # Normalisation [0,1]

                        images.append(img_array)  # Ajouter à la liste
                        image_files.append(file_path)  # Stocker le chemin du fichier
                        name.append(filename)
                        
                    except Exception as e:
                        print(f"❌ Erreur avec l'image {file_name}: {e}")

    # Vérifier que des images ont bien été chargées
    if len(images) == 0:
        raise ValueError("Aucune image originale chargée. Vérifiez le dossier des images originales.")

    return np.array(images), image_files  # Conversion en numpy array après remplissage


# Afficher la liste des fichiers dans og_dir
print("Fichiers dans le dossier :", os.listdir(og_dir))

# Chargement des images
base_array, base_files = load_and_preprocess_original_images(og_dir, size_image_x, size_image_y)

print(f"{len(base_array)} images originales chargées.")
print("Fichiers chargés :", base_files)

# 9. Évaluation sur les images de test
test_images, test_image_files = load_and_preprocess_test_images(test_dir, size_image_x, size_image_y)
print("Test modèle siamois chargé !")

def show_images(images, file_names, title, cols=5):
    num_images = len(images)
    rows = math.ceil(num_images / cols)  # Calcul du nombre de lignes

    plt.figure(figsize=(cols * 3, rows * 3))  # Taille ajustée
    
    for i, (image, file_name) in enumerate(zip(images, file_names)):  
        plt.subplot(rows, cols, i + 1)
        plt.imshow(image, cmap="gray")  # Affichage en niveaux de gris
        plt.title(file_name, fontsize=8)  # Associer image et fichier
        plt.axis("off")

    plt.suptitle(title, fontsize=12)
    plt.tight_layout()
    plt.show()
    
# Afficher les images de test avec une grille plus lisible
show_images(test_images, test_image_files, "Images de test prétraitées")

print(len(test_images))
# Out:
# Fichiers dans le dossier : ['classe1', 'classe100', 'classe11', 'classe15', 'classe17', 'classe18', 'classe19', 'classe2', 'classe20', 'classe22', 'classe24', 'classe25', 'classe26', 'classe28', 'classe3', 'classe30', 'classe31', 'classe32', 'classe33', 'classe34', 'classe36', 'classe37', 'classe38', 'classe39', 'classe4', 'classe40', 'classe41', 'classe42', 'classe44', 'classe45', 'classe46', 'classe47', 'classe48', 'classe49', 'classe50', 'classe51', 'classe52', 'classe53', 'classe54', 'classe55', 'classe57', 'classe58', 'classe59', 'classe6', 'classe60', 'classe61', 'classe62', 'classe64', 'classe68', 'classe7', 'classe70', 'classe71', 'classe73', 'classe74', 'classe75', 'classe76', 'classe77', 'classe78', 'classe79', 'classe81', 'classe82', 'classe84', 'classe87', 'classe89', 'classe9', 'classe90', 'classe91', 'classe92', 'classe96', 'classe98', 'classe99']
# 71 images originales chargées.
# Fichiers chargés : ['D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe1\\patch_0.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe100\\patch_9.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe11\\patch_0.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe15\\patch_4.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe17\\patch_6.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe18\\patch_7.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe19\\patch_8.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe2\\patch_1.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe20\\patch_9.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe22\\patch_1.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe24\\patch_3.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe25\\patch_4.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe26\\patch_5.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe28\\patch_7.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe3\\patch_2.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe30\\patch_9.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe31\\patch_0.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe32\\patch_1.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe33\\patch_2.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe34\\patch_3.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe36\\patch_5.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe37\\patch_6.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe38\\patch_7.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe39\\patch_8.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe4\\patch_3.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe40\\patch_9.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe41\\patch_0.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe42\\patch_1.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe44\\patch_3.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe45\\patch_4.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe46\\patch_5.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe47\\patch_6.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe48\\patch_7.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe49\\patch_8.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe50\\patch_9.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe51\\patch_0.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe52\\patch_1.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe53\\patch_2.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe54\\patch_3.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe55\\patch_4.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe57\\patch_6.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe58\\patch_7.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe59\\patch_8.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe6\\patch_5.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe60\\patch_9.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe61\\patch_0.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe62\\patch_1.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe64\\patch_3.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe68\\patch_7.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe7\\patch_6.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe70\\patch_9.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe71\\patch_0.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe73\\patch_2.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe74\\patch_3.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe75\\patch_4.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe76\\patch_5.png', 'D:\\Lucie\\Insa Toulouse\\4A\\Projet\\petit\\classe77\\patch_6.p ...

# %%
# ÉTAPE DE VÉRIFICATION : Histogramme des similarités
# Prédictions de similarité par le modèle
similarity_scores = siamese_model.predict([X1_train, X2_train])

# Extraire les scores selon le label (1 = paire vraie, 0 = paire fausse)
similarity_scores = similarity_scores.flatten()
true_pairs_scores = similarity_scores[y_train.flatten() == 1]
false_pairs_scores = similarity_scores[y_train.flatten() == 0]

# Affichage de l'histogramme
plt.figure(figsize=(10, 6))
plt.hist(true_pairs_scores, bins=30, alpha=0.7, label='Paires vraies (similaires)', color='green')
plt.hist(false_pairs_scores, bins=30, alpha=0.7, label='Paires fausses (différentes)', color='red')
plt.title("Répartition des scores de similarité selon le type de paire")
plt.xlabel("Score de similarité (proche de 1 = similaire)")
plt.ylabel("Nombre de paires")
plt.legend()
plt.grid(True)
plt.show()

# %%
####### Similarités modèles siamois (Conparaison image par image) ######
def comparer_images(image1, image2):
    """Compare deux images avec le modèle siamois et retourne un score de similarité."""
    # Assurez-vous que l'image est bien un tableau NumPy avec la bonne forme
    image1 = np.expand_dims(image1, axis=0)  # (1, hauteur, largeur, canaux)
    image2 = np.expand_dims(image2, axis=0)  

    # Vérification des dimensions avant d'envoyer au modèle
    #print(f"✅ Forme image1 : {image1.shape}, image2 : {image2.shape}")

    # Passage dans le modèle
    try:
        prediction = siamese_model.predict([image1, image2], verbose=0)
        similarity_score = float(np.mean(prediction))
        return similarity_score
    except Exception as e:
        print(f"❌ Erreur dans la prédiction : {e}")
        return 0.0  # Retourner un score bas en cas d'erreur

# Parcours des images test
for file in test_image_files:
    img_path = os.path.join(test_dir, file)
    try:
        # Charger l'image en niveaux de gris
        image_test = Image.open(img_path).convert("L")  # Convertir en niveaux de gris
        image_test = image_test.resize((size_image_x, size_image_y))  # Redimensionner
        img_array = np.array(image_test, dtype=np.float32) / 255.0  # Normalisation
        
        # Ajouter une dimension de canal pour compatibilité modèle (hauteur, largeur, 1)
        img_array = np.expand_dims(img_array, axis=-1)  

        # Comparer avec chaque image originale
        for i, img_orig in enumerate(base_array):
            img_orig_exp = np.expand_dims(img_orig, axis=-1)  # S'assurer du bon format
            similarity = comparer_images(img_orig_exp, img_array)

            # Déterminer si la correspondance est vraie ou fausse
            statut = "Vrai" if similarity > 0.6 else "Faux"
            print(f"{file}: Similarité avec og {i+1} = {similarity:.4f} - {statut}")

    except Exception as e:
        print(f"❌ Erreur lors du chargement de l'image {file}: {e}")

# Sauvegarde du modèle
siamese_model.save("siamese_model.keras")
print("✅ Modèle sauvegardé.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# chat.jpg: Similarité avec og 1 = 0.0019 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# chat.jpg: Similarité avec og 2 = 0.0013 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# chat.jpg: Similarité avec og 3 = 0.0010 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# chat.jpg: Similarité avec og 4 = 0.0009 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# chat.jpg: Similarité avec og 5 = 0.0012 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# chat.jpg: Similarité avec og 6 = 0.0010 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# chat.jpg: Similarité avec og 7 = 0.0009 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# chat.jpg: Similarité avec og 8 = 0.0006 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# chat.jpg: Similarité avec og 9 = 0.0010 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# chat.jpg: Similarité avec og 10 = 0.0006 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# chat.jpg: Similarité avec og 11 = 0.0019 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# chat.jpg: Similarité avec og 12 = 0.0021 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# chat.jpg: Similarité avec og 13 = 0.0005 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# chat.jpg: Similarité avec og 14 = 0.0005 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# chat.jpg: Similarité avec og 15 = 0.0007 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# chat.jpg: Similarité avec og 16 = 0.0007 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# chat.jpg: Similarité avec og 17 = 0.0044 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# chat.jpg: Similarité avec og 18 = 0.0167 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# chat.jpg: Similarité avec og 19 = 0.0085 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# chat.jpg: Similarité avec og 20 = 0.0056 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# chat.jpg: Similarité avec og 21 = 0.0040 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# chat.jpg: Similarité avec og 22 = 0.0044 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# chat.jpg: Similarité avec og 23 = 0.0030 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# chat.jpg: Similarité avec og 24 = 0.0032 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# chat.jpg: Similarité avec og 25 = 0.0019 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# chat.jpg: Similarité avec og 26 = 0.0054 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# chat.jpg: Similarité avec og 27 = 0.0142 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# chat.jpg: Similarité avec og 28 = 0.0086 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# chat.jpg: Similarité avec og 29 = 0.0129 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# chat.jpg: Similarité avec og 30 = 0.0301 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# chat.jpg: Similarité avec og 31 = 0.0186 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# chat.jpg: Similarité avec og 32 = 0.0161 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# chat.jpg: Similarité avec og 33 = 0.0100 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# chat.jpg: Similarité avec og 34 = 0.0137 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# chat.jpg: Similarité avec og 35 = 0.0220 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# chat.jpg: Similarité avec og 36 = 0.0295 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# chat.jpg: Similarité avec og 37 = 0.0173 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# chat.jpg: Similarité avec og 38 = 0.0132 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# chat.jpg: Similarité avec og 39 = 0.0094 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# chat.jpg: Similarité avec og 40 = 0.0339 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# chat.jpg: Similarité avec og 41 = 0.0355 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# chat.jpg: Similarité avec og 42 = 0.0111 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# chat.jpg: Similarité avec og 43 = 0.0233 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# chat.jpg: Similarité avec og 44 = 0.0005 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# chat.jpg: Similarité avec og 45 = 0.0438 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# chat.jpg: Similarité avec og 46 = 0.1264 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# chat.jpg: Similarité avec og 47 = 0.0365 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# chat.jpg: Similarité avec og 48 = 0.0190 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# chat.jpg: Similarité avec og 49 = 0.0423 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# chat.jpg: Similarité avec og 50 = 0.0005 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# chat.jpg: Similarité avec og 51 = 0.0224 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# chat.jpg: Similarité avec og 52 = 0.0030 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# chat.jpg: Similarité avec og 53 = 0.0018 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# chat.jpg: Similarité avec og 54 = 0.0064 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# chat.jpg: Similarité avec og 55 = 0.0015 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# chat.jpg: Similarité avec og 56 = 0.0015 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# chat.jpg: Similarité avec og 57 = 0.0710 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# chat.jpg: Similarité avec og 58 = 0.0074 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# chat.jpg: Similarité avec og 59 = 0.0021 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# chat.jpg: Similarité avec og 60 = 0.0008 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# chat.jpg: Similarité avec og 61 = 0.0004 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# chat.jpg: Similarité avec og 62 = 0.0004 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# chat.jpg: Similarité avec og 63 = 0.0004 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# chat.jpg: Similarité avec og 64 = 0.0005 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# chat.jpg: Similarité avec og 65 = 0.0005 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# chat.jpg: Similarité avec og 66 = 0.0008 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# chat.jpg: Similarité avec og 67 = 0.0006 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# chat.jpg: Similarité avec og 68 = 0.0007 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# chat.jpg: Similarité avec og 69 = 0.0005 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# chat.jpg: Similarité avec og 70 = 0.0004 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# chat.jpg: Similarité avec og 71 = 0.0004 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# classe10_1.png: Similarité avec og 1 = 0.2156 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe10_1.png: Similarité avec og 2 = 0.2885 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe10_1.png: Similarité avec og 3 = 0.3464 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# classe10_1.png: Similarité avec og 4 = 0.3521 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# classe10_1.png: Similarité avec og 5 = 0.3036 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe10_1.png: Similarité avec og 6 = 0.3274 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_1.png: Similarité avec og 7 = 0.3540 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe10_1.png: Similarité avec og 8 = 0.3557 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe10_1.png: Similarité avec og 9 = 0.3413 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# classe10_1.png: Similarité avec og 10 = 0.3682 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# classe10_1.png: Similarité avec og 11 = 0.2114 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe10_1.png: Similarité avec og 12 = 0.2009 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe10_1.png: Similarité avec og 13 = 0.3151 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_1.png: Similarité avec og 14 = 0.3154 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_1.png: Similarité avec og 15 = 0.3768 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe10_1.png: Similarité avec og 16 = 0.3761 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# classe10_1.png: Similarité avec og 17 = 0.1047 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# classe10_1.png: Similarité avec og 18 = 0.0296 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_1.png: Similarité avec og 19 = 0.0567 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# classe10_1.png: Similarité avec og 20 = 0.0839 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe10_1.png: Similarité avec og 21 = 0.1137 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe10_1.png: Similarité avec og 22 = 0.1054 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# classe10_1.png: Similarité avec og 23 = 0.1484 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_1.png: Similarité avec og 24 = 0.1393 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe10_1.png: Similarité avec og 25 = 0.2168 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# classe10_1.png: Similarité avec og 26 = 0.0864 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# classe10_1.png: Similarité avec og 27 = 0.0347 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# classe10_1.png: Similarité avec og 28 = 0.0565 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_1.png: Similarité avec og 29 = 0.0382 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# classe10_1.png: Similarité avec og 30 = 0.0164 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe10_1.png: Similarité avec og 31 = 0.0266 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# classe10_1.png: Similarité avec og 32 = 0.0307 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe10_1.png: Similarité avec og 33 = 0.0489 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# classe10_1.png: Similarité avec og 34 = 0.0360 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe10_1.png: Similarité avec og 35 = 0.0225 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# classe10_1.png: Similarité avec og 36 = 0.0167 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# classe10_1.png: Similarité avec og 37 = 0.0286 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# classe10_1.png: Similarité avec og 38 = 0.0374 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# classe10_1.png: Similarité avec og 39 = 0.0518 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# classe10_1.png: Similarité avec og 40 = 0.0145 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# classe10_1.png: Similarité avec og 41 = 0.0139 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# classe10_1.png: Similarité avec og 42 = 0.0440 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# classe10_1.png: Similarité avec og 43 = 0.0212 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# classe10_1.png: Similarité avec og 44 = 0.3235 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# classe10_1.png: Similarité avec og 45 = 0.0112 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe10_1.png: Similarité avec og 46 = 0.0035 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# classe10_1.png: Similarité avec og 47 = 0.0135 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# classe10_1.png: Similarité avec og 48 = 0.0260 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe10_1.png: Similarité avec og 49 = 0.0116 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# classe10_1.png: Similarité avec og 50 = 0.3272 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe10_1.png: Similarité avec og 51 = 0.0221 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe10_1.png: Similarité avec og 52 = 0.1452 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# classe10_1.png: Similarité avec og 53 = 0.2267 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# classe10_1.png: Similarité avec og 54 = 0.0747 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# classe10_1.png: Similarité avec og 55 = 0.2505 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe10_1.png: Similarité avec og 56 = 0.2531 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_1.png: Similarité avec og 57 = 0.0067 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe10_1.png: Similarité avec og 58 = 0.0646 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# classe10_1.png: Similarité avec og 59 = 0.1989 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# classe10_1.png: Similarité avec og 60 = 0.3863 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe10_1.png: Similarité avec og 61 = 0.2928 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe10_1.png: Similarité avec og 62 = 0.2642 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe10_1.png: Similarité avec og 63 = 0.2714 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# classe10_1.png: Similarité avec og 64 = 0.3057 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe10_1.png: Similarité avec og 65 = 0.3277 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_1.png: Similarité avec og 66 = 0.3852 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# classe10_1.png: Similarité avec og 67 = 0.3409 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# classe10_1.png: Similarité avec og 68 = 0.3737 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# classe10_1.png: Similarité avec og 69 = 0.2952 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# classe10_1.png: Similarité avec og 70 = 0.2504 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# classe10_1.png: Similarité avec og 71 = 0.2585 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# classe10_2.jpg: Similarité avec og 1 = 0.3865 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe10_2.jpg: Similarité avec og 2 = 0.3261 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe10_2.jpg: Similarité avec og 3 = 0.2682 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# classe10_2.jpg: Similarité avec og 4 = 0.2629 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# classe10_2.jpg: Similarité avec og 5 = 0.3104 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# classe10_2.jpg: Similarité avec og 6 = 0.2859 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 7 = 0.2613 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# classe10_2.jpg: Similarité avec og 8 = 0.1893 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# classe10_2.jpg: Similarité avec og 9 = 0.2737 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# classe10_2.jpg: Similarité avec og 10 = 0.1994 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# classe10_2.jpg: Similarité avec og 11 = 0.3831 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# classe10_2.jpg: Similarité avec og 12 = 0.3714 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# classe10_2.jpg: Similarité avec og 13 = 0.1615 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# classe10_2.jpg: Similarité avec og 14 = 0.1616 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# classe10_2.jpg: Similarité avec og 15 = 0.2059 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# classe10_2.jpg: Similarité avec og 16 = 0.2062 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe10_2.jpg: Similarité avec og 17 = 0.2196 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe10_2.jpg: Similarité avec og 18 = 0.0685 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe10_2.jpg: Similarité avec og 19 = 0.1265 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 20 = 0.1807 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 21 = 0.2359 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe10_2.jpg: Similarité avec og 22 = 0.2208 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# classe10_2.jpg: Similarité avec og 23 = 0.2950 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# classe10_2.jpg: Similarité avec og 24 = 0.2800 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# classe10_2.jpg: Similarité avec og 25 = 0.3824 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe10_2.jpg: Similarité avec og 26 = 0.1855 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# classe10_2.jpg: Similarité avec og 27 = 0.0796 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe10_2.jpg: Similarité avec og 28 = 0.1260 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe10_2.jpg: Similarité avec og 29 = 0.0872 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_2.jpg: Similarité avec og 30 = 0.0386 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# classe10_2.jpg: Similarité avec og 31 = 0.0618 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 32 = 0.0709 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_2.jpg: Similarité avec og 33 = 0.1102 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 34 = 0.0824 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# classe10_2.jpg: Similarité avec og 35 = 0.0525 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_2.jpg: Similarité avec og 36 = 0.0393 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# classe10_2.jpg: Similarité avec og 37 = 0.0662 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# classe10_2.jpg: Similarité avec og 38 = 0.0855 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe10_2.jpg: Similarité avec og 39 = 0.1163 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe10_2.jpg: Similarité avec og 40 = 0.0342 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe10_2.jpg: Similarité avec og 41 = 0.0327 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# classe10_2.jpg: Similarité avec og 42 = 0.0998 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe10_2.jpg: Similarité avec og 43 = 0.0495 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 44 = 0.1670 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe10_2.jpg: Similarité avec og 45 = 0.0265 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 46 = 0.0085 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe10_2.jpg: Similarité avec og 47 = 0.0318 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe10_2.jpg: Similarité avec og 48 = 0.0605 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# classe10_2.jpg: Similarité avec og 49 = 0.0274 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 50 = 0.1693 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 51 = 0.0515 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe10_2.jpg: Similarité avec og 52 = 0.2898 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# classe10_2.jpg: Similarité avec og 53 = 0.3888 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# classe10_2.jpg: Similarité avec og 54 = 0.1627 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# classe10_2.jpg: Similarité avec og 55 = 0.3682 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# classe10_2.jpg: Similarité avec og 56 = 0.3656 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# classe10_2.jpg: Similarité avec og 57 = 0.0160 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# classe10_2.jpg: Similarité avec og 58 = 0.1427 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_2.jpg: Similarité avec og 59 = 0.3702 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe10_2.jpg: Similarité avec og 60 = 0.2313 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe10_2.jpg: Similarité avec og 61 = 0.1474 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# classe10_2.jpg: Similarité avec og 62 = 0.1302 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# classe10_2.jpg: Similarité avec og 63 = 0.1345 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# classe10_2.jpg: Similarité avec og 64 = 0.1555 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# classe10_2.jpg: Similarité avec og 65 = 0.1696 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_2.jpg: Similarité avec og 66 = 0.2319 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# classe10_2.jpg: Similarité avec og 67 = 0.1788 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# classe10_2.jpg: Similarité avec og 68 = 0.2044 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# classe10_2.jpg: Similarité avec og 69 = 0.1489 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_2.jpg: Similarité avec og 70 = 0.1222 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_2.jpg: Similarité avec og 71 = 0.1269 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# classe10_og.jpg: Similarité avec og 1 = 0.3656 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# classe10_og.jpg: Similarité avec og 2 = 0.2825 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# classe10_og.jpg: Similarité avec og 3 = 0.2292 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# classe10_og.jpg: Similarité avec og 4 = 0.2245 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe10_og.jpg: Similarité avec og 5 = 0.2679 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_og.jpg: Similarité avec og 6 = 0.2454 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe10_og.jpg: Similarité avec og 7 = 0.2230 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# classe10_og.jpg: Similarité avec og 8 = 0.1590 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# classe10_og.jpg: Similarité avec og 9 = 0.2342 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# classe10_og.jpg: Similarité avec og 10 = 0.1679 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_og.jpg: Similarité avec og 11 = 0.3707 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# classe10_og.jpg: Similarité avec og 12 = 0.3817 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe10_og.jpg: Similarité avec og 13 = 0.1349 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# classe10_og.jpg: Similarité avec og 14 = 0.1350 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# classe10_og.jpg: Similarité avec og 15 = 0.1735 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe10_og.jpg: Similarité avec og 16 = 0.1739 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_og.jpg: Similarité avec og 17 = 0.2580 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# classe10_og.jpg: Similarité avec og 18 = 0.0833 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe10_og.jpg: Similarité avec og 19 = 0.1518 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# classe10_og.jpg: Similarité avec og 20 = 0.2142 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# classe10_og.jpg: Similarité avec og 21 = 0.2760 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe10_og.jpg: Similarité avec og 22 = 0.2593 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# classe10_og.jpg: Similarité avec og 23 = 0.3400 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# classe10_og.jpg: Similarité avec og 24 = 0.3241 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# classe10_og.jpg: Similarité avec og 25 = 0.3611 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe10_og.jpg: Similarité avec og 26 = 0.2196 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe10_og.jpg: Similarité avec og 27 = 0.0966 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# classe10_og.jpg: Similarité avec og 28 = 0.1512 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_og.jpg: Similarité avec og 29 = 0.1057 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# classe10_og.jpg: Similarité avec og 30 = 0.0472 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe10_og.jpg: Similarité avec og 31 = 0.0752 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe10_og.jpg: Similarité avec og 32 = 0.0862 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe10_og.jpg: Similarité avec og 33 = 0.1328 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe10_og.jpg: Similarité avec og 34 = 0.0999 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# classe10_og.jpg: Similarité avec og 35 = 0.0641 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# classe10_og.jpg: Similarité avec og 36 = 0.0481 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# classe10_og.jpg: Similarité avec og 37 = 0.0805 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe10_og.jpg: Similarité avec og 38 = 0.1036 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe10_og.jpg: Similarité avec og 39 = 0.1399 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# classe10_og.jpg: Similarité avec og 40 = 0.0420 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# classe10_og.jpg: Similarité avec og 41 = 0.0401 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# classe10_og.jpg: Similarité avec og 42 = 0.1205 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# classe10_og.jpg: Similarité avec og 43 = 0.0605 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# classe10_og.jpg: Similarité avec og 44 = 0.1397 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# classe10_og.jpg: Similarité avec og 45 = 0.0325 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# classe10_og.jpg: Similarité avec og 46 = 0.0105 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe10_og.jpg: Similarité avec og 47 = 0.0391 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# classe10_og.jpg: Similarité avec og 48 = 0.0737 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe10_og.jpg: Similarité avec og 49 = 0.0336 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe10_og.jpg: Similarité avec og 50 = 0.1417 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# classe10_og.jpg: Similarité avec og 51 = 0.0629 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe10_og.jpg: Similarité avec og 52 = 0.3347 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# classe10_og.jpg: Similarité avec og 53 = 0.3522 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# classe10_og.jpg: Similarité avec og 54 = 0.1936 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe10_og.jpg: Similarité avec og 55 = 0.3236 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# classe10_og.jpg: Similarité avec og 56 = 0.3208 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_og.jpg: Similarité avec og 57 = 0.0197 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe10_og.jpg: Similarité avec og 58 = 0.1706 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# classe10_og.jpg: Similarité avec og 59 = 0.3862 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# classe10_og.jpg: Similarité avec og 60 = 0.1960 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe10_og.jpg: Similarité avec og 61 = 0.1228 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe10_og.jpg: Similarité avec og 62 = 0.1081 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# classe10_og.jpg: Similarité avec og 63 = 0.1117 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# classe10_og.jpg: Similarité avec og 64 = 0.1298 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# classe10_og.jpg: Similarité avec og 65 = 0.1419 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe10_og.jpg: Similarité avec og 66 = 0.1965 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe10_og.jpg: Similarité avec og 67 = 0.1499 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe10_og.jpg: Similarité avec og 68 = 0.1723 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# classe10_og.jpg: Similarité avec og 69 = 0.1241 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe10_og.jpg: Similarité avec og 70 = 0.1013 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe10_og.jpg: Similarité avec og 71 = 0.1053 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe1_1.jpg: Similarité avec og 1 = 0.1317 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_1.jpg: Similarité avec og 2 = 0.0928 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_1.jpg: Similarité avec og 3 = 0.0716 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# classe1_1.jpg: Similarité avec og 4 = 0.0698 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe1_1.jpg: Similarité avec og 5 = 0.0867 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# classe1_1.jpg: Similarité avec og 6 = 0.0778 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe1_1.jpg: Similarité avec og 7 = 0.0693 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_1.jpg: Similarité avec og 8 = 0.0467 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_1.jpg: Similarité avec og 9 = 0.0735 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_1.jpg: Similarité avec og 10 = 0.0497 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# classe1_1.jpg: Similarité avec og 11 = 0.1346 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe1_1.jpg: Similarité avec og 12 = 0.1422 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# classe1_1.jpg: Similarité avec og 13 = 0.0388 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# classe1_1.jpg: Similarité avec og 14 = 0.0388 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# classe1_1.jpg: Similarité avec og 15 = 0.0516 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# classe1_1.jpg: Similarité avec og 16 = 0.0517 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# classe1_1.jpg: Similarité avec og 17 = 0.2627 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe1_1.jpg: Similarité avec og 18 = 0.2599 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_1.jpg: Similarité avec og 19 = 0.3949 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe1_1.jpg: Similarité avec og 20 = 0.3125 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_1.jpg: Similarité avec og 21 = 0.2453 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_1.jpg: Similarité avec og 22 = 0.2616 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# classe1_1.jpg: Similarité avec og 23 = 0.1930 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# classe1_1.jpg: Similarité avec og 24 = 0.2050 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_1.jpg: Similarité avec og 25 = 0.1305 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# classe1_1.jpg: Similarité avec og 26 = 0.3061 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# classe1_1.jpg: Similarité avec og 27 = 0.2921 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_1.jpg: Similarité avec og 28 = 0.3918 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe1_1.jpg: Similarité avec og 29 = 0.3131 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# classe1_1.jpg: Similarité avec og 30 = 0.1606 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# classe1_1.jpg: Similarité avec og 31 = 0.2392 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe1_1.jpg: Similarité avec og 32 = 0.2668 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_1.jpg: Similarité avec og 33 = 0.3688 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_1.jpg: Similarité avec og 34 = 0.2997 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_1.jpg: Similarité avec og 35 = 0.2094 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_1.jpg: Similarité avec og 36 = 0.1636 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe1_1.jpg: Similarité avec og 37 = 0.2529 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_1.jpg: Similarité avec og 38 = 0.3086 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_1.jpg: Similarité avec og 39 = 0.3831 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe1_1.jpg: Similarité avec og 40 = 0.1450 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_1.jpg: Similarité avec og 41 = 0.1393 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# classe1_1.jpg: Similarité avec og 42 = 0.3456 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_1.jpg: Similarité avec og 43 = 0.1994 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe1_1.jpg: Similarité avec og 44 = 0.0403 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_1.jpg: Similarité avec og 45 = 0.1151 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe1_1.jpg: Similarité avec og 46 = 0.0393 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_1.jpg: Similarité avec og 47 = 0.1359 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe1_1.jpg: Similarité avec og 48 = 0.2353 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_1.jpg: Similarité avec og 49 = 0.1187 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# classe1_1.jpg: Similarité avec og 50 = 0.0410 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe1_1.jpg: Similarité avec og 51 = 0.2061 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# classe1_1.jpg: Similarité avec og 52 = 0.1973 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe1_1.jpg: Similarité avec og 53 = 0.1244 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# classe1_1.jpg: Similarité avec og 54 = 0.3400 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_1.jpg: Similarité avec og 55 = 0.1107 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe1_1.jpg: Similarité avec og 56 = 0.1094 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe1_1.jpg: Similarité avec og 57 = 0.0721 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_1.jpg: Similarité avec og 58 = 0.3741 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# classe1_1.jpg: Similarité avec og 59 = 0.1438 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_1.jpg: Similarité avec og 60 = 0.0594 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# classe1_1.jpg: Similarité avec og 61 = 0.0350 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# classe1_1.jpg: Similarité avec og 62 = 0.0304 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_1.jpg: Similarité avec og 63 = 0.0315 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# classe1_1.jpg: Similarité avec og 64 = 0.0372 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_1.jpg: Similarité avec og 65 = 0.0410 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_1.jpg: Similarité avec og 66 = 0.0596 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# classe1_1.jpg: Similarité avec og 67 = 0.0436 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_1.jpg: Similarité avec og 68 = 0.0511 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# classe1_1.jpg: Similarité avec og 69 = 0.0354 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_1.jpg: Similarité avec og 70 = 0.0283 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe1_1.jpg: Similarité avec og 71 = 0.0295 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# classe1_2.jpg: Similarité avec og 1 = 0.1790 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_2.jpg: Similarité avec og 2 = 0.1283 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_2.jpg: Similarité avec og 3 = 0.0999 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# classe1_2.jpg: Similarité avec og 4 = 0.0974 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# classe1_2.jpg: Similarité avec og 5 = 0.1202 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_2.jpg: Similarité avec og 6 = 0.1082 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe1_2.jpg: Similarité avec og 7 = 0.0967 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe1_2.jpg: Similarité avec og 8 = 0.0658 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# classe1_2.jpg: Similarité avec og 9 = 0.1024 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# classe1_2.jpg: Similarité avec og 10 = 0.0699 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_2.jpg: Similarité avec og 11 = 0.1827 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# classe1_2.jpg: Similarité avec og 12 = 0.1924 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# classe1_2.jpg: Similarité avec og 13 = 0.0549 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_2.jpg: Similarité avec og 14 = 0.0549 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_2.jpg: Similarité avec og 15 = 0.0725 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe1_2.jpg: Similarité avec og 16 = 0.0727 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe1_2.jpg: Similarité avec og 17 = 0.3366 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# classe1_2.jpg: Similarité avec og 18 = 0.1958 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_2.jpg: Similarité avec og 19 = 0.3228 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe1_2.jpg: Similarité avec og 20 = 0.3843 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe1_2.jpg: Similarité avec og 21 = 0.3171 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# classe1_2.jpg: Similarité avec og 22 = 0.3358 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# classe1_2.jpg: Similarité avec og 23 = 0.2554 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe1_2.jpg: Similarité avec og 24 = 0.2699 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# classe1_2.jpg: Similarité avec og 25 = 0.1775 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# classe1_2.jpg: Similarité avec og 26 = 0.3812 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_2.jpg: Similarité avec og 27 = 0.2227 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe1_2.jpg: Similarité avec og 28 = 0.3218 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_2.jpg: Similarité avec og 29 = 0.2404 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# classe1_2.jpg: Similarité avec og 30 = 0.1173 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe1_2.jpg: Similarité avec og 31 = 0.1791 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_2.jpg: Similarité avec og 32 = 0.2018 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_2.jpg: Similarité avec og 33 = 0.2903 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe1_2.jpg: Similarité avec og 34 = 0.2292 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe1_2.jpg: Similarité avec og 35 = 0.1553 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_2.jpg: Similarité avec og 36 = 0.1195 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# classe1_2.jpg: Similarité avec og 37 = 0.1902 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# classe1_2.jpg: Similarité avec og 38 = 0.2365 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe1_2.jpg: Similarité avec og 39 = 0.3030 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_2.jpg: Similarité avec og 40 = 0.1052 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# classe1_2.jpg: Similarité avec og 41 = 0.1010 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_2.jpg: Similarité avec og 42 = 0.2685 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# classe1_2.jpg: Similarité avec og 43 = 0.1473 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_2.jpg: Similarité avec og 44 = 0.0570 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# classe1_2.jpg: Similarité avec og 45 = 0.0827 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# classe1_2.jpg: Similarité avec og 46 = 0.0276 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# classe1_2.jpg: Similarité avec og 47 = 0.0984 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# classe1_2.jpg: Similarité avec og 48 = 0.1760 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# classe1_2.jpg: Similarité avec og 49 = 0.0854 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_2.jpg: Similarité avec og 50 = 0.0579 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_2.jpg: Similarité avec og 51 = 0.1527 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe1_2.jpg: Similarité avec og 52 = 0.2609 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# classe1_2.jpg: Similarité avec og 53 = 0.1696 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe1_2.jpg: Similarité avec og 54 = 0.3825 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe1_2.jpg: Similarité avec og 55 = 0.1518 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# classe1_2.jpg: Similarité avec og 56 = 0.1500 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_2.jpg: Similarité avec og 57 = 0.0512 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# classe1_2.jpg: Similarité avec og 58 = 0.3526 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_2.jpg: Similarité avec og 59 = 0.1944 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe1_2.jpg: Similarité avec og 60 = 0.0833 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# classe1_2.jpg: Similarité avec og 61 = 0.0496 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe1_2.jpg: Similarité avec og 62 = 0.0432 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_2.jpg: Similarité avec og 63 = 0.0447 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_2.jpg: Similarité avec og 64 = 0.0526 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_2.jpg: Similarité avec og 65 = 0.0580 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# classe1_2.jpg: Similarité avec og 66 = 0.0835 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe1_2.jpg: Similarité avec og 67 = 0.0616 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_2.jpg: Similarité avec og 68 = 0.0720 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe1_2.jpg: Similarité avec og 69 = 0.0501 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# classe1_2.jpg: Similarité avec og 70 = 0.0403 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# classe1_2.jpg: Similarité avec og 71 = 0.0420 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# classe1_og.jpg: Similarité avec og 1 = 0.1540 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# classe1_og.jpg: Similarité avec og 2 = 0.1094 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe1_og.jpg: Similarité avec og 3 = 0.0847 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_og.jpg: Similarité avec og 4 = 0.0826 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# classe1_og.jpg: Similarité avec og 5 = 0.1023 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe1_og.jpg: Similarité avec og 6 = 0.0920 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# classe1_og.jpg: Similarité avec og 7 = 0.0820 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# classe1_og.jpg: Similarité avec og 8 = 0.0555 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe1_og.jpg: Similarité avec og 9 = 0.0869 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe1_og.jpg: Similarité avec og 10 = 0.0590 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_og.jpg: Similarité avec og 11 = 0.1573 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# classe1_og.jpg: Similarité avec og 12 = 0.1660 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe1_og.jpg: Similarité avec og 13 = 0.0462 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# classe1_og.jpg: Similarité avec og 14 = 0.0462 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe1_og.jpg: Similarité avec og 15 = 0.0613 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_og.jpg: Similarité avec og 16 = 0.0614 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe1_og.jpg: Similarité avec og 17 = 0.2993 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_og.jpg: Similarité avec og 18 = 0.2264 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe1_og.jpg: Similarité avec og 19 = 0.3641 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_og.jpg: Similarité avec og 20 = 0.3522 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_og.jpg: Similarité avec og 21 = 0.2805 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_og.jpg: Similarité avec og 22 = 0.2982 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# classe1_og.jpg: Similarité avec og 23 = 0.2230 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_og.jpg: Similarité avec og 24 = 0.2363 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe1_og.jpg: Similarité avec og 25 = 0.1526 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe1_og.jpg: Similarité avec og 26 = 0.3457 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe1_og.jpg: Similarité avec og 27 = 0.2561 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_og.jpg: Similarité avec og 28 = 0.3623 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# classe1_og.jpg: Similarité avec og 29 = 0.2756 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe1_og.jpg: Similarité avec og 30 = 0.1376 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# classe1_og.jpg: Similarité avec og 31 = 0.2077 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_og.jpg: Similarité avec og 32 = 0.2329 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# classe1_og.jpg: Similarité avec og 33 = 0.3294 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_og.jpg: Similarité avec og 34 = 0.2632 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# classe1_og.jpg: Similarité avec og 35 = 0.1809 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# classe1_og.jpg: Similarité avec og 36 = 0.1401 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe1_og.jpg: Similarité avec og 37 = 0.2201 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# classe1_og.jpg: Similarité avec og 38 = 0.2713 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# classe1_og.jpg: Similarité avec og 39 = 0.3432 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# classe1_og.jpg: Similarité avec og 40 = 0.1238 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# classe1_og.jpg: Similarité avec og 41 = 0.1188 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# classe1_og.jpg: Similarité avec og 42 = 0.3062 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe1_og.jpg: Similarité avec og 43 = 0.1719 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# classe1_og.jpg: Similarité avec og 44 = 0.0480 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# classe1_og.jpg: Similarité avec og 45 = 0.0977 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_og.jpg: Similarité avec og 46 = 0.0329 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# classe1_og.jpg: Similarité avec og 47 = 0.1159 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# classe1_og.jpg: Similarité avec og 48 = 0.2041 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# classe1_og.jpg: Similarité avec og 49 = 0.1009 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_og.jpg: Similarité avec og 50 = 0.0488 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_og.jpg: Similarité avec og 51 = 0.1779 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_og.jpg: Similarité avec og 52 = 0.2278 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# classe1_og.jpg: Similarité avec og 53 = 0.1457 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# classe1_og.jpg: Similarité avec og 54 = 0.3797 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# classe1_og.jpg: Similarité avec og 55 = 0.1300 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe1_og.jpg: Similarité avec og 56 = 0.1284 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe1_og.jpg: Similarité avec og 57 = 0.0608 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe1_og.jpg: Similarité avec og 58 = 0.3917 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# classe1_og.jpg: Similarité avec og 59 = 0.1678 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# classe1_og.jpg: Similarité avec og 60 = 0.0704 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe1_og.jpg: Similarité avec og 61 = 0.0417 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe1_og.jpg: Similarité avec og 62 = 0.0363 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_og.jpg: Similarité avec og 63 = 0.0376 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_og.jpg: Similarité avec og 64 = 0.0443 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# classe1_og.jpg: Similarité avec og 65 = 0.0489 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# classe1_og.jpg: Similarité avec og 66 = 0.0706 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# classe1_og.jpg: Similarité avec og 67 = 0.0519 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# classe1_og.jpg: Similarité avec og 68 = 0.0608 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# classe1_og.jpg: Similarité avec og 69 = 0.0421 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# classe1_og.jpg: Similarité avec og 70 = 0.0338 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# classe1_og.jpg: Similarité avec og 71 = 0.0352 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# classe2_2.png: Similarité avec og 1 = 0.2725 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# classe2_2.png: Similarité avec og 2 = 0.3545 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# classe2_2.png: Similarité avec og 3 = 0.3903 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# classe2_2.png: Similarité avec og 4 = 0.3853 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# classe2_2.png: Similarité avec og 5 = 0.3729 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# classe2_2.png: Similarité avec og 6 = 0.3947 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe2_2.png: Similarité avec og 7 = 0.3836 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# classe2_2.png: Similarité avec og 8 = 0.2928 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe2_2.png: Similarité avec og 9 = 0.3952 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# classe2_2.png: Similarité avec og 10 = 0.3064 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# classe2_2.png: Similarité avec og 11 = 0.2677 - Faux
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 38
#      36 for i, img_orig in enumerate(base_array):
#      37     img_orig_exp = np.expand_dims(img_orig, axis=-1)  # S'assurer du bon format
# ---> 38     similarity = comparer_images(img_orig_exp, img_array)
#      40     # Déterminer si la correspondance est vraie ou fausse
#      41     statut = "Vrai" if similarity > 0.6 else "Faux"
#
# Cell In[7], line 16, in comparer_images(image1, image2)
#      11 # Vérification des dimensions avant d'envoyer au modèle
#      12 #print(f"✅ Forme image1 : {image1.shape}, image2 : {image2.shape}")
#      13
#      14 # Passage dans le modèle
#      15 try:
# ---> 16     prediction = siamese_model.predict([image1, image2])
#      17     similarity_score = float(np.mean(prediction))
#      18     return similarity_score
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:556, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     554 outputs = None
#     555 with epoch_iterator.catch_stop_iteration():
# --> 556     for step, iterator in epoch_iterator:
#     557         callbacks.on_predict_batch_begin(step)
#     558         data = get_data(iterator)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:729, in TFEpochIterator.__next__(self)
#     728 def __next__(self):
# --> 729     return next(self._epoch_iterator)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\epoch_iterator.py:102, in EpochIterator._enumerate_iterator(self)
#     100 if steps_per_epoch > 0:
#     101     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 102         self._current_iterator = iter(self._get_iterator())
#     103         self._steps_seen = 0
#     104     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3509, in make_iterator(dataset, iterator, name)
#    3507 if tld.is_eager:
#    3508   try:
# -> 3509     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3510       _ctx, "MakeIterator", name, dataset, iterator)
#    3511     return _result
#    3512   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
###########################
####### Similarités modèles siamois (trouver meilleure correspondance) ######
# Fonction pour calculer la meilleure correspondance avec les images de base

## déja dans la cellule d'avant mais si on ne veut pas la run
####### Similarités modèles siamois (Conparaison image par image) ######
def comparer_images(image1, image2):
    """Compare deux images avec le modèle siamois et retourne un score de similarité."""
    # Assurez-vous que l'image est bien un tableau NumPy avec la bonne forme
    image1 = np.expand_dims(image1, axis=0)  # (1, hauteur, largeur, canaux)
    image2 = np.expand_dims(image2, axis=0)  

    try:
        prediction = siamese_model.predict([image1, image2], verbose=0)
        similarity_score = float(np.mean(prediction))
        return similarity_score
    except Exception as e:
        print(f"❌ Erreur dans la prédiction : {e}")
        return 0.0  # Retourner un score bas en cas d'erreur

        
def trouver_meilleure_correspondance(test_image, base_array):
    meilleure_similarite = 0
    meilleure_classe = "Inconnue"
    
    # Comparer chaque image de base avec l'image de test
    for i, img_orig in enumerate(base_array):
        img_orig = np.expand_dims(img_orig, axis=-1)  # Adapter la dimension si besoin
        
        try:
            # Calculer la similarité entre l'image de test et l'image d'origine
            similarity_score = comparer_images(img_orig, test_image)
        except Exception as e:
            print(f"❌ Erreur dans la comparaison : {e}")
            similarity_score = 0
        
        # Mise à jour de la meilleure correspondance
        if similarity_score > meilleure_similarite:
            meilleure_similarite = similarity_score
            meilleure_classe = i + 1  # Ou utiliser base_files[i] pour afficher le nom du fichier
    
    return meilleure_classe, meilleure_similarite

# Phase de test
print("\n--- Phase de Test ---")

# Boucle directement sur les images prétraitées
for img_array, filename in zip(test_images, test_image_files):
    try:
        img_array = np.expand_dims(img_array, axis=-1)  # Adapter la dimension si besoin
        
        # Trouver la meilleure correspondance
        meilleure_classe, score = trouver_meilleure_correspondance(img_array, base_array)
        print(f"✅ {filename} correspond le mieux à la classe {meilleure_classe} avec un score de {score:.4f}")

    except Exception as e:
        print(f"❌ Erreur lors du traitement de {filename} : {e}")
# Out:
# --- Phase de Test ---
# ✅ chat.jpg correspond le mieux à la classe 46 avec un score de 0.0006
# ✅ classe10_1.png correspond le mieux à la classe 63 avec un score de 0.3956
# ✅ classe10_2.jpg correspond le mieux à la classe 60 avec un score de 0.3922
# ✅ classe10_og.jpg correspond le mieux à la classe 3 avec un score de 0.3900
# ✅ classe1_1.jpg correspond le mieux à la classe 53 avec un score de 0.3897
# ✅ classe1_2.jpg correspond le mieux à la classe 56 avec un score de 0.3884
# ✅ classe1_og.jpg correspond le mieux à la classe 55 avec un score de 0.3831
# ✅ classe2_2.png correspond le mieux à la classe 15 avec un score de 0.3976
# ✅ classe2_og.jpg correspond le mieux à la classe 15 avec un score de 0.3958
# ✅ classe3_1.jpg correspond le mieux à la classe 14 avec un score de 0.4009
# ✅ classe3_2.png correspond le mieux à la classe 52 avec un score de 0.3749
# ✅ classe3_og.jpg correspond le mieux à la classe 5 avec un score de 0.3850
# ✅ classe4_1.png correspond le mieux à la classe 7 avec un score de 0.3909
# ✅ classe4_2.jpg correspond le mieux à la classe 26 avec un score de 0.3827
# ✅ classe4_og.jpg correspond le mieux à la classe 60 avec un score de 0.3922
# ✅ classe5_1.png correspond le mieux à la classe 21 avec un score de 0.3762
# ✅ classe5_2.jpg correspond le mieux à la classe 60 avec un score de 0.3965
# ✅ classe5_og.jpg correspond le mieux à la classe 52 avec un score de 0.3833
# ✅ classe6_1.jpg correspond le mieux à la classe 24 avec un score de 0.3976
# ✅ classe6_2.jpg correspond le mieux à la classe 3 avec un score de 0.4064
# ✅ classe6_og.jpg correspond le mieux à la classe 24 avec un score de 0.3971
# ✅ classe7_1.png correspond le mieux à la classe 61 avec un score de 0.4029
# ✅ classe7_2.jpg correspond le mieux à la classe 63 avec un score de 0.4032
# ✅ classe7_og.jpg correspond le mieux à la classe 63 avec un score de 0.3997
# ✅ classe8_1.png correspond le mieux à la classe 60 avec un score de 0.3981
# ✅ classe8_2.jpg correspond le mieux à la classe 7 avec un score de 0.3935
# ✅ classe8_og.jpg correspond le mieux à la classe 4 avec un score de 0.3919
# ✅ classe9_og.jpg correspond le mieux à la classe 66 avec un score de 0.3994
# ✅ faux.jpg correspond le mieux à la classe 70 avec un score de 0.3361
# ✅ faux3.jpg correspond le mieux à la classe 7 avec un score de 0.4037
# ✅ faux4.jpeg correspond le mieux à la classe 70 avec un score de 0.3496
