# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import keras
import import_ipynb
import random 
import math
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras import layers, models, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Lambda, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import backend as K
from PIL import Image
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split 
from tensorflow.keras.applications import VGG16
from sklearn.decomposition import PCA


# 1. Configuration des chemins et paramètres
test_dir = r"C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test"
og_dir = r"C:\Insa\cours4a\projetmulti\Donnees_lucie\petit"
train_dir = r"C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_modifiees"

size_image_x=480
size_image_y=480
input_shape = (size_image_x, size_image_y, 1)

# %%
# Fonction pour charger les images locales
def load_local_images(dataset_path, image_size=(256, 256)):
    images = []
    labels = []
    class_names = sorted(os.listdir(dataset_path))  # Liste des classes

    for label, class_name in enumerate(class_names):
        class_dir = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_dir):
            continue  # Ignorer les fichiers non répertoires

        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            
            # Charger et convertir l'image
            img = load_img(img_path, target_size=image_size, color_mode="grayscale")  
            img_array = img_to_array(img) / 255.0  # Normalisation
            images.append(img_array)
            labels.append(label)

    return np.array(images), np.array(labels)
    
def create_pairs(images, labels):
    imagePairs = []
    labelPairs = []

    num_classes = len(np.unique(labels))
    idx = [np.where(labels == i)[0] for i in range(num_classes)]

    for ind in range(len(images)):
        currImage = images[ind]
        label = labels[ind]

        # Trouver une autre image de la même classe
        indB = np.random.choice(idx[label])
        posImage = images[indB]
        imagePairs.append([currImage, posImage])
        labelPairs.append(1)  # Même classe -> 1

        # Trouver une image d'une autre classe
        neg_idx = np.where(labels != label)[0]
        negImage = images[np.random.choice(neg_idx)]
        imagePairs.append([currImage, negImage])
        labelPairs.append(0)  # Classe différente -> 0

    return np.array(imagePairs, dtype=np.float32), np.array(labelPairs, dtype=np.int32)

x_test, y_test = load_local_images(train_dir)
#x_test = np.expand_dims(x_test, axis=-1)
pairs, labels_pairs = create_pairs(x_test, y_test)
print(f"Nombre total de paires générées : {len(pairs)}")



# Fonction pour charger les images locales
def load_local_images(dataset_path, image_size=(256, 256)):
    images = []
    labels = []
    class_names = sorted(os.listdir(dataset_path))  # Liste des classes

    for label, class_name in enumerate(class_names):
        class_dir = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_dir):
            continue  # Ignorer les fichiers non répertoires

        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            
            # Charger et convertir l'image
            img = load_img(img_path, target_size=image_size, color_mode="grayscale")  
            img_array = img_to_array(img) / 255.0  # Normalisation
            images.append(img_array)
            labels.append(label)

    return np.array(images), np.array(labels)
    
def create_pairs(images, labels):
    imagePairs = []
    labelPairs = []

    num_classes = len(np.unique(labels))
    idx = [np.where(labels == i)[0] for i in range(num_classes)]

    for ind in range(len(images)):
        currImage = images[ind]
        label = labels[ind]

        for i in range(5)
            # Trouver une autre image de la même classe
            indB = np.random.choice(idx[label])
            posImage = images[indB]
            imagePairs.append([currImage, posImage])
            labelPairs.append(1)  # Même classe -> 1
    
            # Trouver une image d'une autre classe
            neg_idx = np.where(labels != label)[0]
            negImage = images[np.random.choice(neg_idx)]
            imagePairs.append([currImage, negImage])
            labelPairs.append(0)  # Classe différente -> 0

    return np.array(imagePairs, dtype=np.float32), np.array(labelPairs, dtype=np.int32)

x_test, y_test = load_local_images(train_dir)
#x_test = np.expand_dims(x_test, axis=-1)
pairs, labels_pairs = create_pairs(x_test, y_test)
print(f"Nombre total de paires générées : {len(pairs)}")
# Out:
# Nombre total de paires générées : 3810
# Nombre total de paires générées : 3810

# %%
########################
###### Modèle Siamois ######
# 4. Création du modèle Siamese
input_shape = (size_image_y, size_image_x, 1)

import tensorflow.keras.backend as K
def contrastive_loss(y_true, y_pred):
    margin = 1.0
    return K.mean(y_true * K.square(y_pred) + (1 - y_true) * K.square(K.maximum(margin - y_pred, 0)))


def create_siamese_model(input_shape):
    """Crée et retourne le modèle Siamese."""
    
    input_img = Input(shape=input_shape)
    
    x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(input_img)
    x = BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dropout(0.2)(x)
    """
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = layers.MaxPooling2D((2, 2))(x)
"""
    output = keras.layers.GlobalAveragePooling2D()(x)  # Reduce spatial dimensions
    #output = layers.Flatten()(output)
    output = keras.layers.Dense(25, activation="sigmoid")(output)
    """
    
    x = layers.Flatten()(x)
    #x = layers.Dense(64, activation='relu')(x)  # Réduction de la taille du vecteur
    x = layers.Dense(128, activation='relu')(x)  # Augmente légèrement la complexité
    """
    output = layers.Dropout(0.3)(output)
    
    siamese = Model(input_img, output, name="siamese")
    siamese.summary()
    
    input_img_1 = Input(shape=input_shape)
    input_img_2 = Input(shape=input_shape)

    encoded_1 = siamese(input_img_1)

    encoded_2 = siamese(input_img_2)

    #distance = layers.Lambda(lambda tensors: tf.abs(tensors[0] - tensors[1]))([encoded_1, encoded_2])
    distance = layers.Lambda(lambda tensors: tf.sqrt(tf.reduce_sum(tf.square(tensors[0] - tensors[1]), axis=1, keepdims=True)))([encoded_1, encoded_2])
    output = layers.Dense(1, activation='sigmoid')(distance)

    siamese_model = Model(inputs=[input_img_1, input_img_2], outputs=output)
    return siamese_model

siamese_model = create_siamese_model(input_shape)

# 6. Compilation et callbacks
#siamese_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])
#siamese_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#siamese_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss=contrastive_loss, metrics=['accuracy'])
siamese_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
# Séparer les paires en deux entrées distinctes
X1 = pairs[:, 0]  # Première image de la paire
X2 = pairs[:, 1]  # Deuxième image de la paire
y = labels_pairs   # Labels (1 si similaires, 0 sinon)

# Création des indices pour les paires
indices = np.arange(len(X1))  # Liste d'indices correspondant aux paires

# Division des indices pour garder les paires intactes
indices_train, indices_val = train_test_split(indices, test_size=0.2, random_state=42)

# Application de la division des indices à X1, X2, et y
X1_train, X2_train, y_train = X1[indices_train], X2[indices_train], y[indices_train]
X1_val, X2_val, y_val = X1[indices_val], X2[indices_val], y[indices_val]

# Redimensionner les images comme avant
X1_train = np.array([cv2.resize(x, (size_image_x, size_image_y)) for x in X1_train], dtype=np.float32)
X2_train = np.array([cv2.resize(x, (size_image_x, size_image_y)) for x in X2_train], dtype=np.float32)

X1_val = np.array([cv2.resize(x, (size_image_x, size_image_y)) for x in X1_val], dtype=np.float32)
X2_val = np.array([cv2.resize(x, (size_image_x, size_image_y)) for x in X2_val], dtype=np.float32)

# Reshaper les labels
y_train = y_train.reshape(-1, 1)
y_val = y_val.reshape(-1, 1)

# Vérification de la cohérence des paires
assert len(X1_train) == len(X2_train) == len(y_train)
assert len(X1_val) == len(X2_val) == len(y_val)

def convert_to_gray(images):
    gray_images = []
    for img in images:
        if img is None:
            raise ValueError("Erreur : Une image n'a pas été chargée correctement.")

        # Vérifier si l'image est déjà en grayscale
        if len(img.shape) == 2:  # Image au format (H, W)
            img = np.expand_dims(img, axis=-1)  # Ajouter une dimension (H, W, 1)
        elif img.shape[-1] == 3:  # Image au format (H, W, 3) (RGB)
            img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # Convertir en grayscale
            img = np.expand_dims(img, axis=-1)  # Ajouter une dimension (H, W, 1)

        gray_images.append(img)

    return np.array(gray_images)

# Appliquer la conversion sur les ensembles d'entraînement et de validation
X1_train = convert_to_gray(X1_train)
X2_train = convert_to_gray(X2_train)
X1_val = convert_to_gray(X1_val)
X2_val = convert_to_gray(X2_val)

# Entraîner le modèle siamois
siamese_model.fit([X1_train, X2_train], y_train, 
                  validation_data=([X1_val, X2_val], y_val), 
                  epochs=3, 
                  batch_size=32, 
                  #callbacks=[early_stopping, reduce_lr]  # Ajout du callback ReduceLROnPlateau
)


#afficher_reconstruction_autoencodeur(train_dir, og_dir, size_image_x, size_image_y, siamese_model)
# Out:
# Model: "siamese"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 120, 120, 1)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 120, 120, 8)         │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 120, 120, 8)         │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 60, 60, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 60, 60, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 60, 60, 16)          │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 60, 60, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 30, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 30, 30, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 16)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 400)                 │           6,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 400)                 │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,144 (31.81 KB)
#  Trainable params: 8,096 (31.62 KB)
#  Non-trainable params: 48 (192.00 B)
# WARNING:tensorflow:From C:\Users\nicol\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/10
# C:\Users\nicol\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\losses\losses.py:27: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(8, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5021 - loss: 0.0000e+00
# C:\Users\nicol\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\losses\losses.py:27: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - accuracy: 0.5021 - loss: 0.0000e+00 - val_accuracy: 0.4331 - val_loss: 0.0000e+00
# Epoch 2/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.5033 - loss: 0.0000e+00 - val_accuracy: 0.3871 - val_loss: 0.0000e+00
# Epoch 3/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.5094 - loss: 0.0000e+00 - val_accuracy: 0.3950 - val_loss: 0.0000e+00
# Epoch 4/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.4846 - loss: 0.0000e+00 - val_accuracy: 0.4016 - val_loss: 0.0000e+00
# Epoch 5/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.5057 - loss: 0.0000e+00 - val_accuracy: 0.3937 - val_loss: 0.0000e+00
# Epoch 6/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.5026 - loss: 0.0000e+00 - val_accuracy: 0.4121 - val_loss: 0.0000e+00
# Epoch 7/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.4775 - loss: 0.0000e+00 - val_accuracy: 0.4278 - val_loss: 0.0000e+00
# Epoch 8/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.4864 - loss: 0.0000e+00 - val_accuracy: 0.4462 - val_loss: 0.0000e+00
# Epoch 9/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.4938 - loss: 0.0000e+00 - val_accuracy: 0.4409 - val_loss: 0.0000e+00
# Epoch 10/10
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.5069 - loss: 0.0000e+00 - val_accuracy: 0.4396 - val_loss: 0.0000e+00

# %%
##################################
### test amélioration -> voir avant couche dense
def visualiser_paire(idx, label):
    """Affiche la comparaison pour une paire donnée (idx) dans le jeu de validation."""
    
    image1 = np.expand_dims(X1_val[idx], axis=0)  # Ajouter batch dim
    image2 = np.expand_dims(X2_val[idx], axis=0)

    # Récupérer l'encodeur Siamese
    encoder_siamois = siamese_model.get_layer("siamese")  

    # 🔹 EXTRACTION DES REPRESENTATIONS LATENTES (Dense)
    latent1 = encoder_siamois.predict(image1)  
    latent2 = encoder_siamois.predict(image2)  

    # 🔹 Trouver la dernière couche 2D avant GlobalAveragePooling2D
    last_conv_layer = None
    for layer in reversed(encoder_siamois.layers):
        if isinstance(layer, layers.Conv2D) or isinstance(layer, layers.MaxPooling2D):
            last_conv_layer = layer
            break

    if last_conv_layer is None:
        raise ValueError("Aucune couche 2D trouvée avant GlobalAveragePooling2D ! Vérifiez l'architecture.")

    model_intermediaire = Model(inputs=encoder_siamois.input, outputs=last_conv_layer.output)
    
    feature_map1 = model_intermediaire.predict(image1)  # Features avant Dense (Image 1)
    feature_map2 = model_intermediaire.predict(image2)  # Features avant Dense (Image 2)

    # 🔹 Normalisation des images pour imshow ([0,255] → [0,1])
    image1_display = np.clip(X1_val[idx] / 255.0, 0, 1)
    image2_display = np.clip(X2_val[idx] / 255.0, 0, 1)

    # Création de la figure
    fig, axes = plt.subplots(3, 3, figsize=(12, 10))

    # 🔹 Affichage des images d'origine
    axes[0, 0].imshow(image1_display)
    axes[0, 0].axis("off")
    axes[0, 0].set_title("Image 1 (Originale)")

    axes[0, 1].imshow(image2_display)
    axes[0, 1].axis("off")
    axes[0, 1].set_title("Image 2 (Comparée)")

    # 🔹 Vérification de la variance avant PCA
    if latent1.shape[1] > 2:
        if np.var(latent1) > 0 and np.var(latent2) > 0:
            pca = PCA(n_components=2)
            latent_pca = pca.fit_transform(np.vstack([latent1, latent2]))

            axes[1, 0].scatter(latent_pca[0, 0], latent_pca[0, 1], c="blue", label="Image 1")
            axes[1, 0].scatter(latent_pca[1, 0], latent_pca[1, 1], c="red", label="Image 2")
            axes[1, 0].legend()
            axes[1, 0].set_title("Représentation Latente (PCA)")
        else:
            axes[1, 0].text(0.5, 0.5, "Variance nulle (PCA impossible)", ha="center", va="center")
            axes[1, 0].axis("off")
    else:
        axes[1, 0].plot(latent1.flatten(), label="Image 1", color="blue")
        axes[1, 0].plot(latent2.flatten(), label="Image 2", color="red")
        axes[1, 0].legend()
        axes[1, 0].set_title("Représentation Latente (Vecteur)")

    # 🔹 Affichage de la différence absolue entre les représentations
    difference = np.abs(latent1 - latent2)
    axes[1, 1].bar(range(len(difference.flatten())), difference.flatten(), color="purple")
    axes[1, 1].set_title("Différence entre Représentations")

    # 🔹 Affichage de la dernière couche 2D avant la Dense (Feature Maps)
    mean_feature1 = np.mean(feature_map1[0], axis=-1)  # Moyenne des cartes de caractéristiques
    mean_feature2 = np.mean(feature_map2[0], axis=-1)

    axes[2, 0].imshow(mean_feature1, cmap="viridis")
    axes[2, 0].set_title("Feature Map Image 1")
    axes[2, 0].axis("off")

    axes[2, 1].imshow(mean_feature2, cmap="viridis")
    axes[2, 1].set_title("Feature Map Image 2")
    axes[2, 1].axis("off")

    # 🔹 Calcul et affichage de la similarité (sortie du modèle Siamese)
    similarity_score = siamese_model.predict([image1, image2])[0, 0]
    label_str = "Similaire" if label == 1 else "Différent"
    
    axes[0, 2].text(0.5, 0.6, f"Score de similarité: {similarity_score:.2f}", fontsize=14, ha="center", va="center")
    axes[0, 2].text(0.5, 0.3, f"Label réel: {label_str}", fontsize=14, color="red", ha="center", va="center")
    axes[0, 2].axis("off")

    plt.tight_layout()
    plt.show()


    
similarity_scores = siamese_model.predict([X1_val, X2_val]).flatten()

# Paires similaires (label = 1)
similar_indices = np.where(y_val == 1)[0]
similar_scores = similarity_scores[similar_indices]
idx_similaire_max_similaires = similar_indices[np.argmax(similar_scores)]
print("🔹 Visualisation paire SIMILAIRE la plus similaire (Label = 1)")
visualiser_paire(idx_similaire_max_similaires, 1)
idx_similaire_min_similaires = similar_indices[np.argmin(similar_scores)]
print("🔹 Visualisation paire SIMILAIRE la moins similaire (Label = 1)")
visualiser_paire(idx_similaire_min_similaires, 1)

# Paires différentes (label = 0)
different_indices = np.where(y_val == 0)[0]
different_scores = similarity_scores[different_indices]
idx_different_max_differents = different_indices[np.argmax(different_scores)]   
print("🔹 Visualisation paire DIFFÉRENTE la plus similaire (Label = 0)")
visualiser_paire(idx_different_max_differents, 0)
idx_different_min_differents = different_indices[np.argmin(different_scores)]   
print("🔹 Visualisation paire DIFFÉRENTE la moins similaire (Label = 0)")
visualiser_paire(idx_different_min_differents, 0)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step
# 🔹 Visualisation paire SIMILAIRE la plus similaire (Label = 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 🔹 Visualisation paire SIMILAIRE la moins similaire (Label = 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# WARNING:tensorflow:5 out of the last 32 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000019A106F5E40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# C:\Users\nicol\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\decomposition\_pca.py:653: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 🔹 Visualisation paire DIFFÉRENTE la plus similaire (Label = 0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 🔹 Visualisation paire DIFFÉRENTE la moins similaire (Label = 0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
################################ NE PAS RUN, PAS LES BONNES IMAGES TEST
####### Chargement données de test ######

# Dimensions pour le redimensionnement
resize_width, resize_height = 480, 256

def cropped_and_gray_image(img_path):
    """Charge une image, détecte un cercle, recadre autour et la convertit en niveaux de gris."""
    # Charger l'image
    image0 = cv2.imread(img_path)

    if image0 is None:
        print(f"Erreur : Impossible de charger {img_path}")
        return None  # Retourner None au lieu de 'continue'

    # Redimensionner l'image à 480x256 pour la détection du cercle
    image = cv2.resize(image0, (resize_width, resize_height))

    # Convertir en niveaux de gris
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Détecter les cercles avec HoughCircles
    circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, dp=1.2, minDist=300, param1=100, param2=10, minRadius=100, maxRadius=200)

    # Dimensions de l'image redimensionnée
    height, width = gray.shape
    center_x, center_y = width // 2, height // 2

    # Sélectionner le cercle le plus proche du centre, mais uniquement s'il est entièrement visible
    best_circle = None
    min_distance = float("inf")

    if circles is not None:
        for circle in circles[0, :]:
            x, y, r = circle

            # Vérifier que le cercle est entièrement contenu dans l'image
            if (x - r >= 0 and y - r >= 0 and x + r <= width and y + r <= height):
                distance_to_center = np.sqrt((x - center_x) ** 2 + (y - center_y) ** 2)
                if distance_to_center < min_distance:
                    min_distance = distance_to_center
                    best_circle = circle
    
    # Si un cercle a été détecté et validé
    if best_circle is not None:
        x, y, r = best_circle  # Coordonnées du cercle sur l'image redimensionnée

        # Mise à l'échelle des coordonnées et du rayon
        scale_x = image0.shape[1] / resize_width
        scale_y = image0.shape[0] / resize_height
        x = int(x * scale_x)
        y = int(y * scale_y)
        r = int(r * min(scale_x, scale_y))  # Adapter le rayon

        # Définir la taille du carré basé sur le diamètre
        side = 2 * r  

        # Calculer les nouvelles coordonnées pour assurer un carré
        x1, y1 = x - r, y - r
        x2, y2 = x + r, y + r

        # Vérifier que les coordonnées restent dans les limites de l'image
        x1, y1 = max(0, x1), max(0, y1)
        x2, y2 = min(image0.shape[1], x2), min(image0.shape[0], y2)

        # Recadrer l'image sur l'image originale
        cropped_image = image0[y1:y2, x1:x2]

        # Convertir en noir et blanc
        cropped_gray = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2GRAY)
        return cropped_gray  # Retourner l'image recadrée et en niveaux de gris
    else : 
        print(f"Aucun cercle trouvé pour: {img_path}")
        return None

def load_and_preprocess_test_images(load_dir, size_image_x, size_image_y):
    """Charge, recadre et prétraite les images de test en niveaux de gris"""
    test_images = []
    valid_file_names = []  # Liste pour stocker les fichiers valides
    test_image_files = [f for f in os.listdir(load_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    for file in test_image_files:
        img_path = os.path.join(load_dir, file)
        try:
            img = cropped_and_gray_image(img_path)  # Récupérer l'image recadrée
            
            if img is not None:  # Si le recadrage a réussi
                img_resized = Image.fromarray(img).resize((size_image_x, size_image_y))
                img_array = np.array(img_resized) / 255.0  # Normalisation [0,1]
                test_images.append(img_array)
                valid_file_names.append(file)  # Ajouter uniquement si l'image est valide
            
        except Exception as e:
            print(f"❌ Erreur avec l'image {file}: {e}")

    if len(test_images) == 0:
        raise ValueError("❌ Aucune image de test chargée. Vérifiez le dossier des images de test.")

    return np.array(test_images), valid_file_names  # Retourne les noms filtrés


def load_and_preprocess_original_images(base_dir, size_image_x, size_image_y):
    """Charge toutes les images des sous-dossiers de base_dir et les prétraite."""
    images = []  # Liste pour stocker les images
    image_files = []  # Liste pour stocker les noms de fichiers
    base_files = [f for f in os.listdir(base_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]


    # Explorer chaque sous-dossier (classe)
    for class_name in os.listdir(base_dir):
        class_path = os.path.join(base_dir, class_name)

        # Vérifier que c'est bien un dossier avant de le parcourir
        if os.path.isdir(class_path):  
            for file_name in os.listdir(class_path):
                file_path = os.path.join(class_path, file_name)

                # Vérifier si c'est une image
                if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                    try:
                        # Charger l'image en niveaux de gris
                        img = Image.open(file_path).convert("L")  # "L" = grayscale
                        img_resized = img.resize((size_image_x, size_image_y))  # Redimensionner
                        img_array = np.array(img_resized) / 255.0  # Normalisation [0,1]

                        images.append(img_array)  # Ajouter à la liste
                        image_files.append(file_path)  # Stocker le chemin du fichier
                        
                    except Exception as e:
                        print(f"❌ Erreur avec l'image {file_name}: {e}")

    # Vérifier que des images ont bien été chargées
    if len(images) == 0:
        raise ValueError("Aucune image originale chargée. Vérifiez le dossier des images originales.")

    return np.array(images), image_files  # Conversion en numpy array après remplissage


# Afficher la liste des fichiers dans og_dir
print("Fichiers dans le dossier :", os.listdir(og_dir))

# Chargement des images
base_array, base_files = load_and_preprocess_original_images(og_dir, size_image_x, size_image_y)

print(f"{len(base_array)} images originales chargées.")
print("Fichiers chargés :", base_files)

# 9. Évaluation sur les images de test
test_images, test_image_files = load_and_preprocess_test_images(test_dir, size_image_x, size_image_y)
print("Test modèle siamois chargé !")

def show_images(images, file_names, title, cols=5):
    num_images = len(images)
    rows = math.ceil(num_images / cols)  # Calcul du nombre de lignes

    plt.figure(figsize=(cols * 3, rows * 3))  # Taille ajustée
    
    for i, (image, file_name) in enumerate(zip(images, file_names)):  
        plt.subplot(rows, cols, i + 1)
        plt.imshow(image, cmap="gray")  # Affichage en niveaux de gris
        plt.title(file_name, fontsize=8)  # Associer image et fichier
        plt.axis("off")

    plt.suptitle(title, fontsize=12)
    plt.tight_layout()
    plt.show()
    
# Afficher les images de test avec une grille plus lisible
show_images(test_images, test_image_files, "Images de test prétraitées")
# Out:
# Fichiers dans le dossier : ['classe1', 'classe100', 'classe11', 'classe15', 'classe17', 'classe18', 'classe19', 'classe2', 'classe20', 'classe22', 'classe24', 'classe25', 'classe26', 'classe28', 'classe3', 'classe30', 'classe31', 'classe32', 'classe33', 'classe34', 'classe36', 'classe37', 'classe38', 'classe39', 'classe4', 'classe40', 'classe41', 'classe42', 'classe44', 'classe45', 'classe46', 'classe47', 'classe48', 'classe49', 'classe50', 'classe51', 'classe52', 'classe53', 'classe54', 'classe55', 'classe57', 'classe58', 'classe59', 'classe6', 'classe60', 'classe61', 'classe62', 'classe64', 'classe68', 'classe7', 'classe70', 'classe71', 'classe73', 'classe74', 'classe75', 'classe76', 'classe77', 'classe78', 'classe79', 'classe81', 'classe82', 'classe84', 'classe87', 'classe89', 'classe9', 'classe90', 'classe91', 'classe92', 'classe96', 'classe98', 'classe99']
# 71 images originales chargées.
# Fichiers chargés : ['C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe1\\patch_0.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe100\\patch_9.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe11\\patch_0.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe15\\patch_4.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe17\\patch_6.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe18\\patch_7.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe19\\patch_8.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe2\\patch_1.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe20\\patch_9.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe22\\patch_1.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe24\\patch_3.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe25\\patch_4.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe26\\patch_5.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe28\\patch_7.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe3\\patch_2.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe30\\patch_9.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe31\\patch_0.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe32\\patch_1.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe33\\patch_2.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe34\\patch_3.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe36\\patch_5.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe37\\patch_6.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe38\\patch_7.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe39\\patch_8.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe4\\patch_3.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe40\\patch_9.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe41\\patch_0.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe42\\patch_1.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe44\\patch_3.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe45\\patch_4.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe46\\patch_5.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe47\\patch_6.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe48\\patch_7.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe49\\patch_8.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe50\\patch_9.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe51\\patch_0.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe52\\patch_1.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe53\\patch_2.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe54\\patch_3.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe55\\patch_4.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe57\\patch_6.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe58\\patch_7.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe59\\patch_8.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe6\\patch_5.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe60\\patch_9.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe61\\patch_0.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe62\\patch_1.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe64\\patch_3.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe68\\patch_7.png', 'C:\\Insa\\cours4a\\projetmulti\\Donnees_lucie\\petit\\classe7\\patch_6.png', 'C:\\Insa\\cours4a\\projetmulti\\Do ...
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe1_1.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe1_2.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe1_3.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe26.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe2_1.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe2_2.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe2_3.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe3.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe89.png
# Aucun cercle trouvé pour: C:\Insa\cours4a\projetmulti\Donnees_lucie\petit_test\classe98.png
# Test modèle siamois chargé !

# %%
####### Similarités modèles siamois (Conparaison image par image) ######
name = []
for filename in os.listdir(test_dir):
    name.append(filename)
def comparer_images(image1, image2):
    """Compare deux images avec le modèle siamois et retourne un score de similarité."""
    # Assurez-vous que l'image est bien un tableau NumPy avec la bonne forme
    image1 = np.expand_dims(image1, axis=0)  # (1, hauteur, largeur, canaux)
    image2 = np.expand_dims(image2, axis=0)  

    # Vérification des dimensions avant d'envoyer au modèle
    #print(f"✅ Forme image1 : {image1.shape}, image2 : {image2.shape}")

    # Passage dans le modèle
    try:
        prediction = siamese_model.predict([image1, image2])
        similarity_score = float(np.mean(prediction))
        return similarity_score
    except Exception as e:
        print(f"❌ Erreur dans la prédiction : {e}")
        return 0.0  # Retourner un score bas en cas d'erreur

# Parcours des images test
for file in test_image_files:
    img_path = os.path.join(test_dir, file)
    try:
        # Charger l'image en niveaux de gris
        image_test = Image.open(img_path).convert("L")  # Convertir en niveaux de gris
        image_test = image_test.resize((size_image_x, size_image_y))  # Redimensionner
        img_array = np.array(image_test, dtype=np.float32) / 255.0  # Normalisation
        
        # Ajouter une dimension de canal pour compatibilité modèle (hauteur, largeur, 1)
        img_array = np.expand_dims(img_array, axis=-1)  

        # Comparer avec chaque image originale
        for i, img_orig in enumerate(base_array):
            img_orig_exp = np.expand_dims(img_orig, axis=-1)  # S'assurer du bon format
            similarity = comparer_images(img_orig_exp, img_array)

            # Déterminer si la correspondance est vraie ou fausse
            statut = "Vrai" if similarity > 0.6 else "Faux"
            print(f"{file}: Similarité avec og {i+1} = {similarity:.4f} - {statut}")

    except Exception as e:
        print(f"❌ Erreur lors du chargement de l'image {file}: {e}")

# Sauvegarde du modèle
siamese_model.save("siamese_model.keras")
print("✅ Modèle sauvegardé.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# classe100.png: Similarité avec og 1 = 0.9879 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 2 = 0.9911 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 3 = 0.9876 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 4 = 0.9878 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# classe100.png: Similarité avec og 5 = 0.9893 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# classe100.png: Similarité avec og 6 = 0.9869 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# classe100.png: Similarité avec og 7 = 0.9883 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 8 = 0.9943 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# classe100.png: Similarité avec og 9 = 0.9907 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 10 = 0.9911 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# classe100.png: Similarité avec og 11 = 0.9855 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# classe100.png: Similarité avec og 12 = 0.9860 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 13 = 0.9948 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# classe100.png: Similarité avec og 14 = 0.9948 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# classe100.png: Similarité avec og 15 = 0.9945 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 16 = 0.9911 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 17 = 0.9841 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 18 = 0.9664 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# classe100.png: Similarité avec og 19 = 0.9765 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# classe100.png: Similarité avec og 20 = 0.9815 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# classe100.png: Similarité avec og 21 = 0.9846 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# classe100.png: Similarité avec og 22 = 0.9831 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# classe100.png: Similarité avec og 23 = 0.9872 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# classe100.png: Similarité avec og 24 = 0.9869 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe100.png: Similarité avec og 25 = 0.9893 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# classe100.png: Similarité avec og 26 = 0.9829 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# classe100.png: Similarité avec og 27 = 0.9738 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 28 = 0.9807 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# classe100.png: Similarité avec og 29 = 0.9782 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# classe100.png: Similarité avec og 30 = 0.9701 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 31 = 0.9700 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# classe100.png: Similarité avec og 32 = 0.9730 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# classe100.png: Similarité avec og 33 = 0.9758 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 34 = 0.9763 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# classe100.png: Similarité avec og 35 = 0.9693 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 36 = 0.9625 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe100.png: Similarité avec og 37 = 0.9687 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# classe100.png: Similarité avec og 38 = 0.9735 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 39 = 0.9788 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 40 = 0.9577 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# classe100.png: Similarité avec og 41 = 0.9605 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# classe100.png: Similarité avec og 42 = 0.9769 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# classe100.png: Similarité avec og 43 = 0.9639 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# classe100.png: Similarité avec og 44 = 0.9952 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# classe100.png: Similarité avec og 45 = 0.9549 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe100.png: Similarité avec og 46 = 0.9235 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# classe100.png: Similarité avec og 47 = 0.9598 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# classe100.png: Similarité avec og 48 = 0.9734 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# classe100.png: Similarité avec og 49 = 0.9559 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 50 = 0.9947 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# classe100.png: Similarité avec og 51 = 0.9700 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 52 = 0.9886 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# classe100.png: Similarité avec og 53 = 0.9897 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe100.png: Similarité avec og 54 = 0.9809 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# classe100.png: Similarité avec og 55 = 0.9913 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 56 = 0.9912 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# classe100.png: Similarité avec og 57 = 0.9484 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# classe100.png: Similarité avec og 58 = 0.9798 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# classe100.png: Similarité avec og 59 = 0.9893 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# classe100.png: Similarité avec og 60 = 0.9938 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# classe100.png: Similarité avec og 61 = 0.9957 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# classe100.png: Similarité avec og 62 = 0.9963 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# classe100.png: Similarité avec og 63 = 0.9963 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 64 = 0.9951 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# classe100.png: Similarité avec og 65 = 0.9955 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# classe100.png: Similarité avec og 66 = 0.9935 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe100.png: Similarité avec og 67 = 0.9945 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# classe100.png: Similarité avec og 68 = 0.9942 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# classe100.png: Similarité avec og 69 = 0.9964 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe100.png: Similarité avec og 70 = 0.9967 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# classe100.png: Similarité avec og 71 = 0.9965 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# classe9.png: Similarité avec og 1 = 0.6589 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# classe9.png: Similarité avec og 2 = 0.5871 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 3 = 0.6657 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# classe9.png: Similarité avec og 4 = 0.6607 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe9.png: Similarité avec og 5 = 0.6307 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# classe9.png: Similarité avec og 6 = 0.6774 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 7 = 0.6517 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# classe9.png: Similarité avec og 8 = 0.4769 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# classe9.png: Similarité avec og 9 = 0.5975 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe9.png: Similarité avec og 10 = 0.5865 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# classe9.png: Similarité avec og 11 = 0.6983 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# classe9.png: Similarité avec og 12 = 0.6908 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# classe9.png: Similarité avec og 13 = 0.4516 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# classe9.png: Similarité avec og 14 = 0.4501 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# classe9.png: Similarité avec og 15 = 0.4646 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 16 = 0.5854 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# classe9.png: Similarité avec og 17 = 0.7181 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# classe9.png: Similarité avec og 18 = 0.8458 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# classe9.png: Similarité avec og 19 = 0.7918 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# classe9.png: Similarité avec og 20 = 0.7484 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 21 = 0.7120 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 22 = 0.7305 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 23 = 0.6715 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# classe9.png: Similarité avec og 24 = 0.6768 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# classe9.png: Similarité avec og 25 = 0.6293 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe9.png: Similarité avec og 26 = 0.7327 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 27 = 0.8093 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe9.png: Similarité avec og 28 = 0.7564 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# classe9.png: Similarité avec og 29 = 0.7782 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 30 = 0.8294 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 31 = 0.8298 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# classe9.png: Similarité avec og 32 = 0.8138 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# classe9.png: Similarité avec og 33 = 0.7965 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# classe9.png: Similarité avec og 34 = 0.7929 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# classe9.png: Similarité avec og 35 = 0.8330 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# classe9.png: Similarité avec og 36 = 0.8600 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 37 = 0.8358 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# classe9.png: Similarité avec og 38 = 0.8113 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 39 = 0.7733 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# classe9.png: Similarité avec og 40 = 0.8745 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# classe9.png: Similarité avec og 41 = 0.8664 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# classe9.png: Similarité avec og 42 = 0.7885 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe9.png: Similarité avec og 43 = 0.8554 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# classe9.png: Similarité avec og 44 = 0.4310 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# classe9.png: Similarité avec og 45 = 0.8817 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# classe9.png: Similarité avec og 46 = 0.9290 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# classe9.png: Similarité avec og 47 = 0.8686 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 48 = 0.8116 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# classe9.png: Similarité avec og 49 = 0.8793 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 50 = 0.4545 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# classe9.png: Similarité avec og 51 = 0.8298 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# classe9.png: Similarité avec og 52 = 0.6455 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 53 = 0.6210 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# classe9.png: Similarité avec og 54 = 0.7545 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# classe9.png: Similarité avec og 55 = 0.5810 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# classe9.png: Similarité avec og 56 = 0.5832 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# classe9.png: Similarité avec og 57 = 0.8957 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# classe9.png: Similarité avec og 58 = 0.7648 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# classe9.png: Similarité avec og 59 = 0.6302 - Vrai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 60 = 0.4952 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# classe9.png: Similarité avec og 61 = 0.4183 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 62 = 0.4572 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 63 = 0.4541 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# classe9.png: Similarité avec og 64 = 0.4366 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# classe9.png: Similarité avec og 65 = 0.4184 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 66 = 0.5076 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# classe9.png: Similarité avec og 67 = 0.4644 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 68 = 0.4815 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# classe9.png: Similarité avec og 69 = 0.4625 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# classe9.png: Similarité avec og 70 = 0.4863 - Faux
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# classe9.png: Similarité avec og 71 = 0.4704 - Faux
# ✅ Modèle sauvegardé.

# %%
###########################
####### Similarités modèles siamois (trouver meilleure correspondance) ######
# Fonction pour calculer la meilleure correspondance avec les images de base

## déja dans la cellule d'avant mais flemme de la run
####### Similarités modèles siamois (Conparaison image par image) ######
def comparer_images(image1, image2):
    """Compare deux images avec le modèle siamois et retourne un score de similarité."""
    # Assurez-vous que l'image est bien un tableau NumPy avec la bonne forme
    image1 = np.expand_dims(image1, axis=0)  # (1, hauteur, largeur, canaux)
    image2 = np.expand_dims(image2, axis=0)  

    # Vérification des dimensions avant d'envoyer au modèle
    #print(f"✅ Forme image1 : {image1.shape}, image2 : {image2.shape}")

    # Passage dans le modèle
    try:
        prediction = siamese_model.predict([image1, image2])
        similarity_score = float(np.mean(prediction))
        return similarity_score
    except Exception as e:
        print(f"❌ Erreur dans la prédiction : {e}")
        return 0.0  # Retourner un score bas en cas d'erreur

        
def trouver_meilleure_correspondance(test_image, base_array):
    meilleure_similarite = 0
    meilleure_classe = "Inconnue"
    
    # Comparer chaque image de base avec l'image de test
    for i, img_orig in enumerate(base_array):
        img_orig = np.expand_dims(img_orig, axis=-1)  # Adapter la dimension si besoin
        
        try:
            # Calculer la similarité entre l'image de test et l'image d'origine
            similarity_score = comparer_images(img_orig, test_image)
        except Exception as e:
            print(f"❌ Erreur dans la comparaison : {e}")
            similarity_score = 0
        
        # Mise à jour de la meilleure correspondance
        if similarity_score > meilleure_similarite:
            meilleure_similarite = similarity_score
            meilleure_classe = i + 1  # Ou utiliser base_files[i] pour afficher le nom du fichier
    
    return meilleure_classe, meilleure_similarite

# Phase de test
print("\n--- Phase de Test ---")

# Boucle directement sur les images prétraitées
for img_array, filename in zip(test_images, test_image_files):
    try:
        img_array = np.expand_dims(img_array, axis=-1)  # Adapter la dimension si besoin
        
        # Trouver la meilleure correspondance
        meilleure_classe, score = trouver_meilleure_correspondance(img_array, base_array)
        print(f"✅ {filename} correspond le mieux à la classe {meilleure_classe} avec un score de {score:.4f}")

    except Exception as e:
        print(f"❌ Erreur lors du traitement de {filename} : {e}")
# Out:
# --- Phase de Test ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# ✅ classe100.png correspond le mieux à la classe 70 avec un score de 0.9896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# ✅ classe9.png correspond le mieux à la classe 70 avec un score de 0.6389

# %%
# ÉTAPE DE VÉRIFICATION : Histogramme des similarités

# Sélectionner un sous-ensemble de paires pour analyse (ex: 500)
num_samples = 200
sample_indices = np.random.choice(len(X1_train), size=num_samples, replace=False)

X1_sample = X1_train[sample_indices]
X2_sample = X2_train[sample_indices]
y_sample = y_train[sample_indices]

# Prédictions de similarité par le modèle
similarity_scores = siamese_model.predict([X1_sample, X2_sample])

# Extraire les scores selon le label (1 = paire vraie, 0 = paire fausse)
similarity_scores = similarity_scores.flatten()
true_pairs_scores = similarity_scores[y_sample.flatten() == 1]
false_pairs_scores = similarity_scores[y_sample.flatten() == 0]

# Affichage de l'histogramme
plt.figure(figsize=(10, 6))
plt.hist(true_pairs_scores, bins=30, alpha=0.7, label='Paires vraies (similaires)', color='green')
plt.hist(false_pairs_scores, bins=30, alpha=0.7, label='Paires fausses (différentes)', color='red')
plt.title("Répartition des scores de similarité selon le type de paire")
plt.xlabel("Score de similarité (proche de 1 = similaire)")
plt.ylabel("Nombre de paires")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
